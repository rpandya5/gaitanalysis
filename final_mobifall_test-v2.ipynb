# %% [markdown]
# **Kaggle Version**

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'mobifall-dataset-v20:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F1057926%2F1779436%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240811%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240811T185609Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Failed to load (likely expired) https://storage.googleapis.com/kaggle-data-sets/1057926/1779436/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240811%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240811T185609Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=... to path /kaggle/input/mobifall-dataset-v20
# Data source import complete.

# %%
import numpy as np
import pandas as pd
import os

def identify_type(file_name):
    file_name = file_name[:len(file_name)-3]
    activity = file_name.split('_')
    if not (activity[1] == 'acc' or activity[1]=='gyro'):
        col1 = 'Azimuth'
        col2 = 'Pitch'
        col3 = 'Roll'
    elif activity[1] == 'acc':
        col1 = 'X_Acc'
        col2 = 'Y_Acc'
        col3 = 'Z_Acc'
    else:
        col1 = 'X_Gyro'
        col2 = 'Y_Gyro'
        col3 = 'Z_Gyro'
    return activity[0], activity[2], activity[1], activity[3], col1, col2, col3

def convert_txt_to_df(folder_path, file_name):
    os.chdir(folder_path)
    with open(file_name, 'r') as txtfile:
        text = txtfile.read()

    text = text[text.index('@DATA')+len('@DATA')+1:]
    time_readings = text.split('\n')
    file_df = []
    for readings in time_readings:
        readings = readings.split(',')
        file_df.append(readings)
    _, _, _, _, col1, col2, col3 = identify_type(file_name)
    file_df = pd.DataFrame(file_df, columns=['Timestamp', col1, col2, col3])
    return file_df.iloc[:-1,:]

output_folder = '/kaggle/working/'
os.chdir(output_folder)
os.mkdir('FALL')
os.mkdir('NO FALL')
folders = ['FALL', 'NO FALL']
for folder in folders:
    os.chdir(os.path.join(output_folder, folder))
    for sub in range(1, 22):
        os.mkdir('sub'+str(sub))
    os.mkdir('sub29')
    os.mkdir('sub30')
    os.mkdir('sub31')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-91513d2e70a0> in <cell line: 38>()
#      36
#      37 output_folder = '/kaggle/working/'
# ---> 38 os.chdir(output_folder)
#      39 os.mkdir('FALL')
#      40 os.mkdir('NO FALL')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/'

# %%
fall = ['FOL', 'FKL', 'BSC', 'SDL']
no_fall = ['STD', 'WAL', 'JOG', 'JUM', 'STU', 'STN', 'SCH', 'CSI', 'CSO']
for dirname, _, filenames in os.walk('/kaggle/input/'):
    for filename in filenames:
        if filename != 'Readme.txt':
            activity, person, trial, _, _, _, _ = identify_type(filename)
            df = convert_txt_to_df(dirname, filename)
            path = '/kaggle/working/'
            if activity in fall:
                path = path + 'FALL/'
            else:
                path = path + 'NO FALL/'
            path = path + 'sub' + person + '/'
            path = path + filename.rstrip('.txt') + '.csv'
            df.to_csv(path, index=False)
            #print(path)

# %%
def merge_sample(df_acc, df_gyro):
  df_acc['Timestamp'] = pd.to_datetime(df_acc['Timestamp'])
  df_acc.set_index('Timestamp', inplace=True)
  df_acc = df_acc.resample('100ms').mean()
  df_acc = df_acc.interpolate(method='linear')
  df_acc.reset_index(inplace=True)

  df_gyro['Timestamp'] = pd.to_datetime(df_gyro['Timestamp'])
  df_gyro.set_index('Timestamp', inplace=True)
  df_gyro = df_gyro.resample('100ms').mean()
  df_gyro = df_gyro.interpolate(method='linear')
  df_gyro.reset_index(inplace=True)


  merged = pd.merge(df_acc, df_gyro, on='Timestamp', how='outer')
  merged.ffill(inplace=True)
  merged.set_index('Timestamp', inplace=True)
  merged = merged.sort_index()
  merged.reset_index(inplace=True)
  merged.bfill(inplace=True)
  merged.rename(columns={'X_Acc': 'X_Acc_1', 'Y_Acc': 'Y_Acc_1', 'Z_Acc': 'Z_Acc_1'}, inplace=True)
  merged['X_Acc_1'] = merged['X_Acc_1'] * -1
  merged['Y_Acc_1'] = merged['Y_Acc_1'] * -1
  merged['Z_Acc_1'] = merged['Z_Acc_1'] * -1
  merged['X_Gyro'] = merged['X_Gyro'] * -180/3.14
  merged['Y_Gyro'] = merged['Y_Gyro'] * -180/3.14
  merged['Z_Gyro'] = merged['Z_Gyro'] * -180/3.14
  return merged

# %%
class DataProcessing:
  def __init__(self, window_size = 400, window_overlap = 200):

    #Features we extract from the windows
    self.features = ['X_Acc_Mean', 'X_Acc_Max', 'X_Acc_Std', 'X_Acc_Min',
                     'X_Acc_IQR', 'X_Acc_Skew', 'X_Acc_Kurtosis', 'X_Acc_Energy', 'X_Acc_Jerk',
                     'Y_Acc_Mean', 'Y_Acc_Max', 'Y_Acc_Std', 'Y_Acc_Min',
                     'Y_Acc_IQR', 'Y_Acc_Skew', 'Y_Acc_Kurtosis', 'Y_Acc_Energy', 'Y_Acc_Jerk',
                     'Z_Acc_Mean', 'Z_Acc_Max', 'Z_Acc_Std', 'Z_Acc_Min',
                     'Z_Acc_IQR', 'Z_Acc_Skew', 'Z_Acc_Kurtosis', 'Z_Acc_Energy', 'Z_Acc_Jerk',
                     'XY_Acc_Cov', 'X_Gyro_Mean', 'X_Gyro_Max', 'X_Gyro_Std', 'X_Gyro_Min',
                     'X_Gyro_IQR', 'X_Gyro_Skew', 'X_Gyro_Kurtosis', 'X_Gyro_Energy', 'X_Gyro_Jerk',
                     'Y_Gyro_Mean', 'Y_Gyro_Max', 'Y_Gyro_Std', 'Y_Gyro_Min',
                     'Y_Gyro_IQR', 'Y_Gyro_Skew', 'Y_Gyro_Kurtosis', 'Y_Gyro_Energy', 'Y_Gyro_Jerk',
                     'Z_Acc_Mean', 'Z_Gyro_Max', 'Z_Gyro_Std', 'Z_Gyro_Min',
                     'Z_Gyro_IQR', 'Z_Gyro_Skew', 'Z_Gyro_Kurtosis', 'Z_Gyro_Energy', 'Z_Gyro_Jerk',
                     'XY_Gyro_Cov']

    self.window_size = window_size # window size is 2 seconds
    self.window_overlap = window_overlap # Overlap is 1 second

  #Feature Extraction Done by Anya and Nick
  def getcov(self, x_list_1, x_bar ,y_list, y_bar):
    """ Calculates the covariance of x and y in the selected window.

    Parameters:
    -----------
        x_list_1 : list
        x_bar :
          Average of x list
        y_list : list
        y_bar : float
          Average of y list

    Returns:
    --------
        covariace of x and y : float

    """
    cov = []
    for i in range(len(x_list_1)):
        cov.append((x_list_1[i] - x_bar) * (y_list[i] - y_bar))
    return sum(cov) / len(x_list_1) - 1

  def jerk(self, x_list, t_step):
    """ Calculated jerk, or the rate of change of the acceleration.

    Parameters:
    -----------
    x_list : list
    t_step : float

    Returns:
    --------
    jerk_list : list

    """
    jerk_list = []
    for i in range(len(x_list)-1):
        jerk_list.append((x_list[i+1] - x_list[i]) / t_step)

    jerk_list.append(jerk_list[-1])
    return sum(jerk_list) / len(jerk_list)

  def energy(self, x_list):
    """ Avergaged energy of the corresponding window

    Parameters:
    -----------
    x_list : list

    Returns:
    --------
    energy : float

    """
    sum = 0
    for i in range(len(x_list)):
        sum += x_list[i]**2
    return sum / len(x_list)


  #Nick add your functions here (also add self as the first parameter)
  def butter_lowpass_filter(self, data, cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    y = filtfilt(b, a, data)
    return y

  def getmean(self,df, col):
    """if col in (0,1,2,6,7,8):
      x = butter_lowpass_filter(df[col], 10, 100)
    else:"""
    x = df[col]
    return x.mean()

  def getstd(self,df, col):
    """if col in (0,1,2,6,7,8):
      x = butter_lowpass_filter(df[col], 10, 100)
    else:"""
    x = df[col]
    return x.std()

  def getmin(self, df, col):
    """if col in (0,1,2,6,7,8):
      x = butter_lowpass_filter(df[col], 10, 100)
    else:"""
    x = df[col]
    return x.min()

  def getmax(self, df, col):
    """if col in (0,1,2,6,7,8):
      x = butter_lowpass_filter(df[col], 10, 100)
    else:"""
    x = df[col]
    return x.max()

  def getmedian(self, df, col):
    """if col in (0,1,2,6,7,8):
      x = butter_lowpass_filter(df[col], 10, 100)
    else:"""
    x = df[col]
    return x.median()

  def getskewness(self, df, col):
    """if col in (0,1,2,6,7,8):
      x = butter_lowpass_filter(df[col], 10, 100)
    else:"""
    x = df[col]
    return x.skew()

  def getkurtosis(self, df, col):
    """ if col in (0,1,2,6,7,8):
      x = butter_lowpass_filter(df[col], 10, 100)
    else:"""
    x = df[col]
    return x.kurtosis()

  def getiqr(self, df, col):
    """ if col in (0,1,2,6,7,8):
      x = butter_lowpass_filter(df[col], 10, 100)
    else:"""
    x = df[col]
    return x.quantile(0.75) - x.quantile(0.25)
  #Window Sampling done by Krish
  def window_sample(self, file_df):
    """
    Description: Converts sensor readings of 15 seconds (200 Hz) into windows

    Inputs:   dir- path to the directory where the file is stored
              file- Name of the file with the sensor data

    Outputs:  DataFrame with the windows and features extracted
    """

    #Window size for activities is 2 seconds with a one second overlap
    window_x = 1
    new_df = []
    for i in range(0, len(file_df)-self.window_overlap, self.window_overlap):
      window = file_df.iloc[i:i+self.window_size:]
      sampled = []

      #Calling all functions for the specific window
      sampled.append(self.getmean(window, 'X_Acc_1'))
      sampled.append(self.getmax(window, 'X_Acc_1'))
      sampled.append(self.getstd(window, 'X_Acc_1'))
      sampled.append(self.getmin(window, 'X_Acc_1'))
      sampled.append(self.getiqr(window, 'X_Acc_1'))
      sampled.append(self.getskewness(window, 'X_Acc_1'))
      sampled.append(self.getkurtosis(window, 'X_Acc_1'))
      sampled.append(self.energy(window['X_Acc_1'].tolist()))
      sampled.append(self.jerk(window['X_Acc_1'].tolist(), (2/self.window_size)))

      sampled.append(self.getmean(window, 'Y_Acc_1'))
      sampled.append(self.getmax(window, 'Y_Acc_1'))
      sampled.append(self.getstd(window, 'Y_Acc_1'))
      sampled.append(self.getmin(window, 'Y_Acc_1'))
      sampled.append(self.getiqr(window, 'Y_Acc_1'))
      sampled.append(self.getskewness(window, 'Y_Acc_1'))
      sampled.append(self.getkurtosis(window, 'Y_Acc_1'))
      sampled.append(self.energy(window['Y_Acc_1'].tolist()))
      sampled.append(self.jerk(window['Y_Acc_1'].tolist(), (2/self.window_size)))

      sampled.append(self.getmean(window, 'Z_Acc_1'))
      sampled.append(self.getmax(window, 'Z_Acc_1'))
      sampled.append(self.getstd(window, 'Z_Acc_1'))
      sampled.append(self.getmin(window, 'Z_Acc_1'))
      sampled.append(self.getiqr(window, 'Z_Acc_1'))
      sampled.append(self.getskewness(window, 'Z_Acc_1'))
      sampled.append(self.getkurtosis(window, 'Z_Acc_1'))
      sampled.append(self.energy(window['Z_Acc_1'].tolist()))
      sampled.append(self.jerk(window['Z_Acc_1'].tolist(), (2/self.window_size)))
      sampled.append(self.getcov(window['X_Acc_1'].tolist(), self.getmean(window, 'X_Acc_1'), window['Y_Acc_1'].tolist(), self.getmean(window, 'Y_Acc_1')))


      sampled.append(self.getmean(window, 'X_Gyro'))
      sampled.append(self.getmax(window, 'X_Gyro'))
      sampled.append(self.getstd(window, 'X_Gyro'))
      sampled.append(self.getmin(window, 'X_Gyro'))
      sampled.append(self.getiqr(window, 'X_Gyro'))
      sampled.append(self.getskewness(window, 'X_Gyro'))
      sampled.append(self.getkurtosis(window, 'X_Gyro'))
      sampled.append(self.energy(window['X_Gyro'].tolist()))
      sampled.append(self.jerk(window['X_Gyro'].tolist(), (2/self.window_size)))

      sampled.append(self.getmean(window, 'Y_Gyro'))
      sampled.append(self.getmax(window, 'Y_Gyro'))
      sampled.append(self.getstd(window, 'Y_Gyro'))
      sampled.append(self.getmin(window, 'Y_Gyro'))
      sampled.append(self.getiqr(window, 'Y_Gyro'))
      sampled.append(self.getskewness(window, 'Y_Gyro'))
      sampled.append(self.getkurtosis(window, 'Y_Gyro'))
      sampled.append(self.energy(window['Y_Gyro'].tolist()))
      sampled.append(self.jerk(window['Y_Gyro'].tolist(), (2/self.window_size)))

      sampled.append(self.getmean(window, 'Z_Gyro'))
      sampled.append(self.getmax(window, 'Z_Gyro'))
      sampled.append(self.getstd(window, 'Z_Gyro'))
      sampled.append(self.getmin(window, 'Z_Gyro'))
      sampled.append(self.getiqr(window, 'Z_Gyro'))
      sampled.append(self.getskewness(window, 'Z_Gyro'))
      sampled.append(self.getkurtosis(window, 'Z_Gyro'))
      sampled.append(self.energy(window['Z_Gyro'].tolist()))
      sampled.append(self.jerk(window['Z_Gyro'].tolist(), (2/self.window_size)))
      sampled.append(self.getcov(window['X_Gyro'].tolist(), self.getmean(window, 'X_Gyro'), window['Y_Gyro'].tolist(), self.getmean(window, 'Y_Gyro')))

      new_df.append(sampled)
      window_x += 1

    #Returns the created DataFrame
    return pd.DataFrame(new_df, columns=self.features)

# %%
def get_activity_data(activity=['STD', 'WAL', 'JOG', 'JUM', 'SCH', 'STU', 'STN', 'CSI', 'CSO', 'FOL', 'FKL', 'SDL', 'BSC']):
  sampler = DataProcessing(20, 10)
  mobidata = []
  mobilabels = []
  for dir, _, files in os.walk('/kaggle/working'):
    for file in files:
      if file[4:7]=='acc' and file[:3] in activity:
        print(file)
        df_acc = pd.read_csv(os.path.join(dir, file))
        df_gyro = pd.read_csv(os.path.join(dir, file[:4]+'gyro'+file[7:]))
        file_df = merge_sample(df_acc, df_gyro)
        file_sampled = sampler.window_sample(file_df)
        if len(file_sampled)>14:
          file_sampled = np.array(file_sampled[:14])
        elif len(file_sampled)<14:
          file_sampled_np = np.array(file_sampled)
          file_sampled = np.vstack((file_sampled_np, np.tile(file_sampled_np[-1], (14-len(file_sampled), 1))))
        if file[:3] in ['BSC', 'FOL', 'FKL', 'SDL']:
          mobilabels.append(1)
        else:
          mobilabels.append(0)
        mobidata.append(file_sampled)
  return mobidata, mobilabels

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
import random
import pandas as pd
import os

# %%
#Helper Functions
def plot_train_val(epoch_list, train_loss, val_loss, title):
    # Plotting

  fig, ax = plt.subplots(figsize=(6, 5))

  plt.title(title+" Curve")

  colors = ["#8D99AE", "#EF233C"]
  # Plot the baseline text
  plt.text(
    epoch_list[-1] * 1.01,
    train_loss[-1],
    "Training " + title,
    color=colors[0],
    fontweight="bold",
    horizontalalignment="left",
    verticalalignment="center",
  )
  plt.text(
    epoch_list[-1] * 1.01,
    val_loss[-1],
    "Validation " + title,
    color=colors[1],
    fontweight="bold",
    horizontalalignment="left",
    verticalalignment="center",
  )
  # Hide the all but the bottom spines (axis lines)
  ax.spines["right"].set_visible(False)
  #ax.spines["left"].set_visible(False)
  ax.spines["top"].set_visible(False)

  # Only show ticks on the left and bottom spines
  ax.yaxis.set_ticks_position("left")
  ax.xaxis.set_ticks_position("bottom")
  #ax.spines["bottom"].set_bounds(min(x), max(x))


  plt.plot(epoch_list, train_loss, label="Train", color = colors[0], linewidth = 2)
  plt.plot(epoch_list, val_loss, label="Validation", color = colors[1], linewidth = 2)
  plt.xlabel("Epoch")
  plt.ylabel(title)
  plt.legend(loc='best')
  plt.show()

def train(model, data, val_data, batch_size = 64, lr = 0.01, epoch_num = 100):
  #train_queue = tf.train.slice_input_producer([data, train_labels],num_epochs=epoch_num,batch_size = batch_size,shuffle=True)

  train_loader = torch.utils.data.DataLoader(data, batch_size = batch_size)
  #val_queue = tf.train.slice_input_producer([val_data, val_labels], num_epochs=epoch_num,batch_size = batch_size, shuffle=True)
  val_loader = torch.utils.data.DataLoader(val_data, batch_size = batch_size)

  criterion = nn.BCEWithLogitsLoss()
  optimizer  = torch.optim.Adam(model.parameters(),lr=lr)

  train_err, val_err, train_acc, val_acc = [], [], [], []

  train_t1_err, train_t2_err, val_t1_err, val_t2_err = [], [], [], []

  v_out = []

  epoch_list = range(epoch_num)
  num = 0

  train_loss = []
  val_loss = []
  loss_temp = []

  for epoch in epoch_list:

    error = 0
    count = 0
    t1_err = 0
    t2_err = 0

    for sample, labels in iter(train_loader):
      count += 1
      out = model(sample)         # Compute the output
      loss = criterion(out, labels) # Compute the total loss
      loss.backward()               # Backward pass
      optimizer.step()              # make the updates for each parameter
      optimizer.zero_grad()         # PyTorch clean up

      # Recalculating the out for the updated model step.
      out = model(sample)
      loss = criterion(out, labels)
      # Save the current training information
      loss_temp.append(float(loss)/batch_size)
      out = torch.sigmoid(out) # Gets the decimal estimations of fall / no fall
      estimate = torch.round(out) # Rounds each estimate to 1 or 0 --> fall or no fall

      type1_error = F.relu(estimate - labels) # Gets all the type 1 errors (predicted fall with no fall)
      type2_error = F.relu(labels - estimate) # Gets all the type 2 errors (predicted no fall with fall)


      diff = torch.abs(estimate - labels, out=None) # Gets all the incorrect assessments equal to 1
      temp = torch.sum(diff) # Sums all the error estimates
      error = temp.item() + error
      t1_err += torch.sum(type1_error).item()
      t2_err += torch.sum(type2_error).item()

    train_acc.append(1 - error/len(data))
    train_err.append(error/len(data))
    train_loss.append(sum(loss_temp)/len(loss_temp))

    train_t1_err.append(t1_err/len(data))
    train_t2_err.append(t2_err/len(data))
    error = 0
    t1_err = 0
    t2_err = 0

    # computing the error and accuracy on a validation set
    loss_temp = []
    count = 0
    error = 0
    v_out = torch.tensor([])
    for sample, labels in iter(val_loader):
      count += 1
      out = model(sample)
      loss = criterion(out, labels)
      out = torch.sigmoid(out) # Gets the decimal estimations of fall / no fall
      estimate = torch.round(out) # Rounds each estimate to 1 or 0 --> fall or no fall
      diff = torch.abs(estimate - labels, out=None) # Gets all the incorrect assessments equal to 1
      temp = torch.sum(diff) # Sums all the error estimates
      error = temp.item() + error

      loss_temp.append(float(loss)/batch_size)
      type1_error = F.relu(estimate - labels) # Gets all the type 1 errors (predicted fall with no fall)
      type2_error = F.relu(labels - estimate) # Gets all the type 2 errors (predicted no fall with fall)
      t1_err += torch.sum(type1_error).item()
      t2_err += torch.sum(type2_error).item()
      v_out = torch.cat((v_out, out))


    val_err.append(error/len(val_data))
    val_acc.append(1 - error/len(val_data))
    val_loss.append(sum(loss_temp)/len(loss_temp))

    val_t1_err.append(t1_err/len(val_data))
    val_t2_err.append(t2_err/len(val_data))

    print("\n\nEpoch ", epoch, "\nTraining Loss         : ",round(train_loss[-1],2), "\nTraining Accuracy     : ", round(train_acc[-1],2), "\nValidation Loss       : ", round(val_loss[-1],2), "\nValidation Accuracy   : ", round(val_acc[-1],2))

  v_out = v_out.view(-1).cpu().detach().numpy()
  plot_train_val(epoch_list, train_loss, val_loss, "Loss")
  plot_train_val(epoch_list, train_acc, val_acc, "Accuracy")
  plot_train_val(epoch_list, train_err, val_err, "Error")

  return v_out

def get_labels(data):
  #Returns the labels
  list = []
  for elem in data:
    list.append(int(elem[-1]))
  return list

def listOfTuples(l1, l2):
  #Merging
  return list(map(lambda x, y:(x,y), l1, l2))

def get_acc(model, data, batch_size):
  correct = 0
  total = 0
  error = 0
  out_list = torch.tensor([])
  for img, labels in torch.utils.data.DataLoader(data, batch_size = batch_size):
    output = model(img)
    output = torch.sigmoid(output) # Gets the decimal estimations of fall / no fall
    estimate = torch.round(output) # Rounds each estimate to 1 or 0 --> fall or no fall
    diff = torch.abs(estimate - labels, out=None) # Gets all the incorrect assessments equal to 1
    temp = torch.sum(diff) # Sums all the error estimates
    error = temp.item() + error

    out_list = torch.cat((out_list, output))

  label_list = get_labels(data)
  out_list = out_list.view(-1).cpu().detach().numpy()
  out_list = [round(i) for i in out_list]
  confusion_matrix_2 = metrics.confusion_matrix(label_list, out_list)
  cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix_2, display_labels = [0, 1])

  cm_display.plot()
  plt.show()

  return 1 - error / len(data)

# %%
class NoNormModel(nn.Module):
  def __init__(self, input_size):
    super(NoNormModel, self).__init__()

    # CNN LAYERS
    self.cnn_layers = nn.Sequential(

        # LAYER 1: 64 filters, kernel size 3, relu, batch norm, maxpooling size 2 (reduce dim)
        nn.Conv1d(in_channels=input_size, out_channels=64, kernel_size=3, padding=1),
        nn.ReLU(),
        nn.MaxPool1d(kernel_size=2),

        # LAYER 2 128 filters, kernel size 3, relu, batch norm, maxpooling size 2
        nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
        nn.ReLU(),
        nn.MaxPool1d(kernel_size=2),

        # LAYER 3 256 filters, kernel size 3, relu, batch norm, maxpooling size 2
        nn.Conv1d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
        nn.ReLU(),
        nn.MaxPool1d(kernel_size=2),
    )

    # LSTM LAYERS

    # 256 input from cnn, 100 units
    self.lstm_1 = nn.LSTM(input_size=256, hidden_size=100, batch_first=True)

    # 100 input from lstm1, 100 units, return false
    self.lstm_2 = nn.LSTM(input_size=100, hidden_size=100, batch_first=True)

    self.fully_connected = nn.Sequential(

        # First Fully Connected Layer 100 Inputs, 100 Outputs
        nn.Linear(100, 100),
        nn.ReLU(),
        # Dropout Layer
        nn.Dropout(0.5),

        # Second Fully Connected Layer, 100 Inputs, 1 Output
        nn.Linear(100, 1)
    )

  def forward(self, x):
    x = x.permute(0, 2, 1) # change shape to (batch_size, input_channels, time_steps)

    cnn_out = self.cnn_layers(x) #shape is now: (batch_size, 256, time_steps // 8)

    lstm_in = cnn_out.permute(0, 2 , 1) #change to batch_size, time_steps // 8, 256) for lstm inpiut

    lstm_out, _ = self.lstm_1(lstm_in)
    lstm_out, _ = self.lstm_2(lstm_out)

    fully_connected_in = lstm_out.view(-1, 100) # reshape to (batch_size, 100)
    fully_connected_out = self.fully_connected(fully_connected_in)
    fully_connected_out = fully_connected_out.view(-1)
    fully_connected_out = fully_connected_out.to(torch.float)

    return fully_connected_out

# %%
model_6 = torch.load('/content/gdrive/MyDrive/Copy of model_6.pth')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-256d26231ce5> in <cell line: 1>()
# ----> 1 model_6 = torch.load('/content/gdrive/MyDrive/Copy of model_6.pth')
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     995         pickle_load_args['encoding'] = 'utf-8'
#     996
# --> 997     with _open_file_like(f, 'rb') as opened_file:
#     998         if _is_zipfile(opened_file):
#     999             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     442 def _open_file_like(name_or_buffer, mode):
#     443     if _is_path(name_or_buffer):
# --> 444         return _open_file(name_or_buffer, mode)
#     445     else:
#     446         if 'w' in mode:
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     423 class _open_file(_opener):
#     424     def __init__(self, name, mode):
# --> 425         super().__init__(open(name, mode))
#     426
#     427     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/Copy of model_6.pth'

# %%
model_6.eval()

# %%
def pred_activity(activity=['STD', 'WAL', 'JOG', 'JUM', 'SCH', 'STU', 'STN', 'CSI', 'CSO', 'FOL', 'FKL', 'SDL', 'BSC']):
  mobidata, mobilabels = get_activity_data(activity)
  mobidata = np.array(mobidata)
  mobilabels = np.array(mobilabels)
  mobicombined = (listOfTuples((torch.from_numpy(mobidata)).to(torch.float), torch.from_numpy(mobilabels).to(torch.float)))
  random.shuffle(mobicombined)
  print(get_acc(model_6, mobicombined, 64))

# %%
pred_activity()

# %% [markdown]
# **Updated MobiFall v2 shared by BMI with Annotated Readings and extra samples**

# %%
# !unzip '/content/gdrive/MyDrive/APS 360 /MobiAct_Dataset_v2.0.rar'
# Out:
# unzip:  cannot find or open /content/gdrive/MyDrive/APS 360 /MobiAct_Dataset_v2.0.rar, /content/gdrive/MyDrive/APS 360 /MobiAct_Dataset_v2.0.rar.zip or /content/gdrive/MyDrive/APS 360 /MobiAct_Dataset_v2.0.rar.ZIP.

# %%
# !pip install unrar
# Out:
# Requirement already satisfied: unrar in /usr/local/lib/python3.10/dist-packages (0.4)

# %%
import os
os.chdir('/content/')

# %%
# !unrar x '/content/gdrive/MyDrive/APS360 Project/MobiAct_Dataset_v2.0.rar'

# %%
import pandas as pd
file_df = pd.read_csv('/content/MobiAct_Dataset_v2.0/Annotated Data/CSI/CSI_10_1_annotated.csv')
file_df = file_df.drop(['timestamp', 'azimuth', 'pitch', 'roll', 'label'], axis=1)
file_df # A sample how it looks

# %%
import torch
model_6 = torch.load('/content/gdrive/MyDrive/APS360 Project/saved_models/Copy of model_6.pth')

# %%
model_6.eval()
# Out:
# NoNormModel(
#   (cnn_layers): Sequential(
#     (0): Conv1d(56, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv1d(64, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#     (4): ReLU()
#     (5): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#     (7): ReLU()
#     (8): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (lstm_1): LSTM(256, 100, batch_first=True)
#   (lstm_2): LSTM(100, 100, batch_first=True)
#   (fully_connected): Sequential(
#     (0): Linear(in_features=100, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=100, out_features=1, bias=True)
#   )
# )

# %%
sampler = DataProcessing()
mobidata = []
mobilabels = []
for dir, _, files in os.walk('/content/MobiAct_Dataset_v2.0/Annotated Data'):
  for file in files:
    if file[:3] in ['STD', 'WAL', 'STU', 'STN', 'SIT', 'JOG', 'JUM', 'CSI', 'CSO', 'FOL', 'FKL', 'SDL', 'BSC']:
      print(file)
      file_df = pd.read_csv(os.path.join(dir, file))
      file_df = file_df.drop(['timestamp', 'azimuth', 'pitch', 'roll', 'label'], axis=1)
      file_df.rename(columns={'rel_time': 'Timestamp', 'acc_x': 'X_Acc_1', 'acc_y': 'Y_Acc_1', 'acc_z': 'Z_Acc_1','gyro_x': 'X_Gyro', 'gyro_y': 'Y_Gyro', 'gyro_z': 'Z_Gyro'}, inplace=True)
      file_df['X_Acc_1'] = file_df['X_Acc_1'] * -1
      file_df['Y_Acc_1'] = file_df['Y_Acc_1'] * -1
      file_df['Z_Acc_1'] = file_df['Z_Acc_1'] * -1
      file_df['X_Gyro'] = file_df['X_Gyro'] * -180/3.14
      file_df['Y_Gyro'] = file_df['Y_Gyro'] * -180/3.14
      file_df['Z_Gyro'] = file_df['Z_Gyro'] * -180/3.14
      if file[:3] in ['FOL', 'FKL', 'SDL', 'BSC']:
        last_row = file_df.tail(1)
        new_rows = pd.concat([last_row]*(3000-len(file_df)), ignore_index=True)
        file_df = pd.concat([file_df, new_rows], ignore_index=True)
        file_sampled = sampler.window_sample(file_df)
        mobidata.append(file_sampled)
        mobilabels.append(1)
      elif file[:3] in ['STD', 'WAL']:
        for i in range(0, 57000, 3000):
          file_df_i = file_df[i:i+3000]
          file_sampled = sampler.window_sample(file_df_i)
          mobidata.append(file_sampled)
          mobilabels.append(0)
      elif file[:3] in ['STU', 'STN', 'SIT', 'JOG', 'JUM', 'CSI', 'CSO']:
        if len(file_df)>3000:
          file_df = file_df[:3000]
        elif len(file_df)<3000:
          last_row = file_df.tail(1)
          new_rows = pd.concat([last_row]*(3000-len(file_df)), ignore_index=True)
          file_df = pd.concat([file_df, new_rows], ignore_index=True)
        file_sampled = sampler.window_sample(file_df)
        mobidata.append(file_sampled)
        mobilabels.append(0)
# Out:
# CSO_54_2_annotated.csv
# CSO_10_4_annotated.csv
# CSO_19_2_annotated.csv
# CSO_61_5_annotated.csv
# CSO_12_3_annotated.csv
# CSO_47_3_annotated.csv
# CSO_8_3_annotated.csv
# CSO_43_6_annotated.csv
# CSO_36_4_annotated.csv
# CSO_62_4_annotated.csv
# CSO_33_1_annotated.csv
# CSO_4_4_annotated.csv
# CSO_51_5_annotated.csv
# CSO_38_2_annotated.csv
# CSO_51_1_annotated.csv
# CSO_27_1_annotated.csv
# CSO_9_2_annotated.csv
# CSO_40_3_annotated.csv
# CSO_65_4_annotated.csv
# CSO_34_2_annotated.csv
# CSO_40_6_annotated.csv
# CSO_58_4_annotated.csv
# CSO_29_2_annotated.csv
# CSO_47_2_annotated.csv
# CSO_32_6_annotated.csv
# CSO_54_1_annotated.csv
# CSO_48_4_annotated.csv
# CSO_1_4_annotated.csv
# CSO_12_6_annotated.csv
# CSO_59_6_annotated.csv
# CSO_8_4_annotated.csv
# CSO_24_3_annotated.csv
# CSO_42_6_annotated.csv
# CSO_39_1_annotated.csv
# CSO_64_1_annotated.csv
# CSO_16_1_annotated.csv
# CSO_2_1_annotated.csv
# CSO_19_4_annotated.csv
# CSO_55_5_annotated.csv
# CSO_42_2_annotated.csv
# CSO_21_1_annotated.csv
# CSO_66_1_annotated.csv
# CSO_63_4_annotated.csv
# CSO_52_1_annotated.csv
# CSO_29_3_annotated.csv
# CSO_36_3_annotated.csv
# CSO_56_4_annotated.csv
# CSO_20_2_annotated.csv
# CSO_35_2_annotated.csv
# CSO_48_1_annotated.csv
# CSO_28_4_annotated.csv
# CSO_11_3_annotated.csv
# CSO_7_2_annotated.csv
# CSO_32_1_annotated.csv
# CSO_37_3_annotated.csv
# CSO_53_5_annotated.csv
# CSO_5_6_annotated.csv
# CSO_53_6_annotated.csv
# CSO_64_5_annotated.csv
# CSO_36_1_annotated.csv
# CSO_39_3_annotated.csv
# CSO_18_4_annotated.csv
# CSO_67_6_annotated.csv
# CSO_41_5_annotated.csv
# CSO_43_1_annotated.csv
# CSO_41_4_annotated.csv
# CSO_54_4_annotated.csv
# CSO_28_1_annotated.csv
# CSO_1_2_annotated.csv
# CSO_7_1_annotated.csv
# CSO_55_4_annotated.csv
# CSO_40_2_annotated.csv
# CSO_4_2_annotated.csv
# CSO_18_2_annotated.csv
# CSO_53_4_annotated.csv
# CSO_6_5_annotated.csv
# CSO_24_6_annotated.csv
# CSO_53_3_annotated.csv
# CSO_26_5_annotated.csv
# CSO_58_1_annotated.csv
# CSO_43_2_annotated.csv
# CSO_49_5_annotated.csv
# CSO_29_5_annotated.csv
# CSO_65_5_annotated.csv
# CSO_60_4_annotated.csv
# CSO_58_3_annotated.csv
# CSO_10_1_annotated.csv
# CSO_11_1_annotated.csv
# CSO_65_1_annotated.csv
# CSO_22_1_annotated.csv
# CSO_51_6_annotated.csv
# CSO_65_6_annotated.csv
# CSO_9_3_annotated.csv
# CSO_38_4_annotated.csv
# CSO_8_1_annotated.csv
# CSO_64_4_annotated.csv
# CSO_27_3_annotated.csv
# CSO_16_4_annotated.csv
# CSO_3_6_annotated.csv
# CSO_57_2_annotated.csv
# CSO_8_6_annotated.csv
# CSO_18_6_annotated.csv
# CSO_43_4_annotated.csv
# CSO_41_3_annotated.csv
# CSO_4_5_annotated.csv
# CSO_37_5_annotated.csv
# CSO_59_3_annotated.csv
# CSO_66_4_annotated.csv
# CSO_58_5_annotated.csv
# CSO_22_5_annotated.csv
# CSO_55_6_annotated.csv
# CSO_29_1_annotated.csv
# CSO_12_2_annotated.csv
# CSO_2_5_annotated.csv
# CSO_16_5_annotated.csv
# CSO_25_1_annotated.csv
# CSO_2_2_annotated.csv
# CSO_56_2_annotated.csv
# CSO_9_5_annotated.csv
# CSO_64_6_annotated.csv
# CSO_27_6_annotated.csv
# CSO_66_6_annotated.csv
# CSO_58_6_annotated.csv
# CSO_57_1_annotated.csv
# CSO_52_4_annotated.csv
# CSO_56_5_annotated.csv
# CSO_26_2_annotated.csv
# CSO_7_5_annotated.csv
# CSO_61_6_annotated.csv
# CSO_38_3_annotated.csv
# CSO_43_5_annotated.csv
# CSO_65_3_annotated.csv
# CSO_38_6_annotated.csv
# CSO_62_5_annotated.csv
# CSO_5_3_annotated.csv
# CSO_34_5_annotated.csv
# CSO_20_1_annotated.csv
# CSO_62_2_annotated.csv
# CSO_39_5_annotated.csv
# CSO_3_5_annotated.csv
# CSO_1_3_annotated.csv
# CSO_45_6_annotated.csv
# CSO_46_2_annotated.csv
# CSO_9_6_annotated.csv
# CSO_45_1_annotated.csv
# CSO_58_2_annotated.csv
# CSO_59_1_annotated.csv
# CSO_39_6_annotated.csv
# CSO_9_1_annotated.csv
# CSO_42_4_annotated.csv
# CSO_51_2_annotated.csv
# CSO_6_4_annotated.csv
# CSO_2_4_annotated.csv
# CSO_37_1_annotated.csv
# CSO_61_1_annotated.csv
# CSO_53_2_annotated.csv
# CSO_63_5_annotated.csv
# CSO_18_3_annotated.csv
# CSO_22_6_annotated.csv
# CSO_19_3_annotated.csv
# CSO_16_3_annotated.csv
# CSO_36_2_annotated.csv
# CSO_32_5_annotated.csv
# CSO_40_4_annotated.csv
# CSO_42_5_annotated.csv
# CSO_34_4_annotated.csv
# CSO_21_3_annotated.csv
# CSO_40_5_annotated.csv
# CSO_67_1_annotated.csv
# CSO_41_2_annotated.csv
# CSO_67_2_annotated.csv
# CSO_28_2_annotated.csv
# CSO_19_5_annotated.csv
# CSO_25_2_annotated.csv
# CSO_46_4_annotated.csv
# CSO_4_6_annotated.csv
# CSO_19_1_annotated.csv
# CSO_45_5_annotated.csv
# CSO_63_1_annotated.csv
# CSO_37_2_annotated.csv
# CSO_65_2_annotated.csv
# CSO_60_3_annotated.csv
# CSO_56_1_annotated.csv
# CSO_61_2_annotated.csv
# CSO_27_2_annotated.csv
# CSO_11_2_annotated.csv
# CSO_53_1_annotated.csv
# CSO_64_2_annotated.csv
# CSO_52_6_annotated.csv
# CSO_18_5_annotated.csv
# CSO_57_6_annotated.csv
# CSO_39_4_annotated.csv
# CSO_23_2_annotated.csv
# CSO_10_5_annotated.csv
# CSO_34_3_annotated.csv
# CSO_10_6_annotated.csv
# CSO_26_1_annotated.csv
# CSO_21_2_annotated.csv
# CSO_49_6_annotated.csv
# CSO_23_4_annotated.csv
# CSO_48_3_annotated.csv
# CSO_47_4_annotated.csv
# CSO_24_4_annotated.csv
# CSO_39_2_annotated.csv
# CSO_63_6_annotated.csv
# CSO_26_6_annotated.csv
# CSO_11_4_annotated.csv
# CSO_18_1_annotated.csv
# CSO_5_1_annotated.csv
# CSO_3_4_annotated.csv
# CSO_45_2_annotated.csv
# CSO_6_2_annotated.csv
# CSO_67_4_annotated.csv
# CSO_35_3_annotated.csv
# CSO_8_2_annotated.csv
# CSO_3_3_annotated.csv
# CSO_41_1_annotated.csv
# CSO_6_6_annotated.csv
# CSO_42_1_annotated.csv
# CSO_47_5_annotated.csv
# CSO_48_6_annotated.csv
# CSO_44_6_annotated.csv
# CSO_62_3_annotated.csv
# CSO_66_5_annotated.csv
# CSO_8_5_annotated.csv
# CSO_51_4_annotated.csv
# CSO_60_5_annotated.csv
# CSO_11_5_annotated.csv
# CSO_48_2_annotated.csv
# CSO_9_4_annotated.csv
# CSO_44_5_annotated.csv
# CSO_3_2_annotated.csv
# CSO_4_1_annotated.csv
# CSO_47_1_annotated.csv
# CSO_21_4_annotated.csv
# CSO_29_6_annotated.csv
# CSO_56_3_annotated.csv
# CSO_21_6_annotated.csv
# CSO_25_4_annotated.csv
# CSO_20_5_annotated.csv
# CSO_22_4_annotated.csv
# CSO_12_5_annotated.csv
# CSO_44_1_annotated.csv
# CSO_52_3_annotated.csv
# CSO_23_6_annotated.csv
# CSO_32_2_annotated.csv
# CSO_44_4_annotated.csv
# CSO_20_4_annotated.csv
# CSO_44_2_annotated.csv
# CSO_44_3_annotated.csv
# CSO_51_3_annotated.csv
# CSO_52_5_annotated.csv
# CSO_3_1_annotated.csv
# CSO_36_5_annotated.csv
# CSO_16_2_annotated.csv
# CSO_19_6_annotated.csv
# CSO_7_4_annotated.csv
# CSO_55_2_annotated.csv
# CSO_34_6_annotated.csv
# CSO_32_3_annotated.csv
# CSO_33_3_annotated.csv
# CSO_35_5_annotated.csv
# CSO_28_3_annotated.csv
# CSO_47_6_annotated.csv
# CSO_20_6_annotated.csv
# CSO_33_2_annotated.csv
# CSO_55_3_annotated.csv
# CSO_26_4_annotated.csv
# CSO_12_4_annotated.csv
# CSO_49_3_annotated.csv
# CSO_60_1_annotated.csv
# CSO_41_6_annotated.csv
# CSO_59_4_annotated.csv
# CSO_46_1_annotated.csv
# CSO_33_6_annotated.csv
# CSO_5_5_annotated.csv
# CSO_45_4_annotated.csv
# CSO_59_2_annotated.csv
# CSO_49_1_annotated.csv
# CSO_61_4_annotated.csv
# CSO_2_6_annotated.csv
# CSO_1_1_annotated.csv
# CSO_52_2_annotated.csv
# CSO_46_6_annotated.csv
# CSO_66_2_annotated.csv
# CSO_37_6_annotated.csv
# CSO_36_6_annotated.csv
# CSO_25_5_annotated.csv
# CSO_62_6_annotated.csv
# CSO_33_5_annotated.csv
# CSO_62_1_annotated.csv
# CSO_57_3_annotated.csv
# CSO_35_1_annotated.csv
# CSO_60_6_annotated.csv
# CSO_29_4_annotated.csv
# CSO_35_4_annotated.csv
# CSO_4_3_annotated.csv
# CSO_1_6_annotated.csv
# CSO_7_6_annotated.csv
# CSO_55_1_annotated.csv
# CSO_27_4_annotated.csv
# CSO_24_5_annotated.csv
# CSO_35_6_annotated.csv
# CSO_16_6_annotated.csv
# CSO_49_2_annotated.csv
# CSO_60_2_annotated.csv
# CSO_67_5_annotated.csv
# CSO_23_1_annotated.csv
# CSO_34_1_annotated.csv
# CSO_54_6_annotated.csv
# CSO_48_5_annotated.csv
# CSO_25_6_annotated.csv
# CSO_21_5_annotated.csv
# CSO_63_3_annotated.csv
# CSO_42_3_annotated.csv
# CSO_5_4_annotated.csv
# CSO_38_5_annotated.csv
# CSO_7_3_annotated.csv
# CSO_2_3_annotated.csv
# CSO_27_5_annotated.csv
# CSO_10_2_annotated.csv
# CSO_28_5_annotated.csv
# CSO_57_5_annotated.csv
# CSO_67_3_annotated.csv
# CSO_33_4_annotated.csv
# CSO_28_6_annotated.csv
# CSO_37_4_annotated.csv
# CSO_24_1_annotated.csv
# CSO_23_3_annotated.csv
# CSO_11_6_annotated.csv
# CSO_25_3_annotated.csv
# CSO_5_2_annotated.csv
# CSO_22_3_annotated.csv
# CSO_6_1_annotated.csv
# CSO_32_4_annotated.csv
# CSO_26_3_annotated.csv
# CSO_6_3_annotated.csv
# CSO_43_3_annotated.csv
# CSO_1_5_annotated.csv
# CSO_46_3_annotated.csv
# CSO_40_1_annotated.csv
# CSO_66_3_annotated.csv
# CSO_61_3_annotated.csv
# CSO_12_1_annotated.csv
# CSO_54_3_annotated.csv
# CSO_59_5_annotated.csv
# CSO_46_5_annotated.csv
# CSO_57_4_annotated.csv
# CSO_45_3_annotated.csv
# CSO_38_1_annotated.csv
# CSO_10_3_annotated.csv
# CSO_54_5_annotated.csv
# CSO_49_4_annotated.csv
# CSO_64_3_annotated.csv
# CSO_22_2_annotated.csv
# CSO_24_2_annotated.csv
# CSO_20_3_annotated.csv
# CSO_23_5_annotated.csv
# CSO_63_2_annotated.csv
# CSO_56_6_annotated.csv
# FOL_48_2_annotated.csv
# FOL_11_3_annotated.csv
# FOL_25_1_annotated.csv
# FOL_18_3_annotated.csv
# FOL_12_1_annotated.csv
# FOL_18_2_annotated.csv
# FOL_58_3_annotated.csv
# FOL_59_2_annotated.csv
# FOL_2_2_annotated.csv
# FOL_35_3_annotated.csv
# FOL_17_2_annotated.csv
# FOL_54_2_annotated.csv
# FOL_61_2_annotated.csv
# FOL_29_1_annotated.csv
# FOL_55_1_annotated.csv
# FOL_34_1_annotated.csv
# FOL_4_1_annotated.csv
# FOL_42_3_annotated.csv
# FOL_31_3_annotated.csv
# FOL_45_3_annotated.csv
# FOL_51_3_annotated.csv
# FOL_23_1_annotated.csv
# FOL_15_2_annotated.csv
# FOL_43_3_annotated.csv
# FOL_20_2_annotated.csv
# FOL_27_3_annotated.csv
# FOL_67_2_annotated.csv
# FOL_16_3_annotated.csv
# FOL_27_2_annotated.csv
# FOL_26_2_annotated.csv
# FOL_3_3_annotated.csv
# FOL_7_3_annotated.csv
# FOL_7_2_annotated.csv
# FOL_6_2_annotated.csv
# FOL_7_1_annotated.csv
# FOL_48_1_annotated.csv
# FOL_13_3_annotated.csv
# FOL_22_1_annotated.csv
# FOL_39_1_annotated.csv
# FOL_10_3_annotated.csv
# FOL_37_1_annotated.csv
# FOL_40_2_annotated.csv
# FOL_62_1_annotated.csv
# FOL_25_2_annotated.csv
# FOL_36_3_annotated.csv
# FOL_30_2_annotated.csv
# FOL_65_3_annotated.csv
# FOL_38_3_annotated.csv
# FOL_22_2_annotated.csv
# FOL_56_1_annotated.csv
# FOL_20_1_annotated.csv
# FOL_45_2_annotated.csv
# FOL_19_2_annotated.csv
# FOL_63_2_annotated.csv
# FOL_5_3_annotated.csv
# FOL_52_3_annotated.csv
# FOL_9_2_annotated.csv
# FOL_19_1_annotated.csv
# FOL_5_1_annotated.csv
# FOL_28_2_annotated.csv
# FOL_13_1_annotated.csv
# FOL_57_1_annotated.csv
# FOL_1_1_annotated.csv
# FOL_64_1_annotated.csv
# FOL_15_3_annotated.csv
# FOL_12_3_annotated.csv
# FOL_22_3_annotated.csv
# FOL_18_1_annotated.csv
# FOL_16_2_annotated.csv
# FOL_17_3_annotated.csv
# FOL_66_1_annotated.csv
# FOL_56_3_annotated.csv
# FOL_48_3_annotated.csv
# FOL_10_2_annotated.csv
# FOL_19_3_annotated.csv
# FOL_39_2_annotated.csv
# FOL_42_2_annotated.csv
# FOL_23_2_annotated.csv
# FOL_28_1_annotated.csv
# FOL_66_2_annotated.csv
# FOL_26_1_annotated.csv
# FOL_44_1_annotated.csv
# FOL_58_2_annotated.csv
# FOL_57_2_annotated.csv
# FOL_4_2_annotated.csv
# FOL_60_3_annotated.csv
# FOL_65_2_annotated.csv
# FOL_58_1_annotated.csv
# FOL_28_3_annotated.csv
# FOL_31_2_annotated.csv
# FOL_16_1_annotated.csv
# FOL_44_3_annotated.csv
# FOL_66_3_annotated.csv
# FOL_40_3_annotated.csv
# FOL_59_1_annotated.csv
# FOL_40_1_annotated.csv
# FOL_54_1_annotated.csv
# FOL_33_1_annotated.csv
# FOL_54_3_annotated.csv
# FOL_26_3_annotated.csv
# FOL_1_2_annotated.csv
# FOL_44_2_annotated.csv
# FOL_53_1_annotated.csv
# FOL_5_2_annotated.csv
# FOL_33_3_annotated.csv
# FOL_56_2_annotated.csv
# FOL_62_3_annotated.csv
# FOL_51_1_annotated.csv
# FOL_9_1_annotated.csv
# FOL_37_3_annotated.csv
# FOL_14_3_annotated.csv
# FOL_42_1_annotated.csv
# FOL_3_1_annotated.csv
# FOL_63_1_annotated.csv
# FOL_29_3_annotated.csv
# FOL_32_3_annotated.csv
# FOL_46_3_annotated.csv
# FOL_52_1_annotated.csv
# FOL_36_1_annotated.csv
# FOL_21_3_annotated.csv
# FOL_57_3_annotated.csv
# FOL_60_1_annotated.csv
# FOL_6_1_annotated.csv
# FOL_36_2_annotated.csv
# FOL_43_1_annotated.csv
# FOL_47_1_annotated.csv
# FOL_49_1_annotated.csv
# FOL_4_3_annotated.csv
# FOL_55_2_annotated.csv
# FOL_63_3_annotated.csv
# FOL_61_3_annotated.csv
# FOL_38_2_annotated.csv
# FOL_23_3_annotated.csv
# FOL_8_3_annotated.csv
# FOL_46_1_annotated.csv
# FOL_53_3_annotated.csv
# FOL_35_2_annotated.csv
# FOL_64_2_annotated.csv
# FOL_13_2_annotated.csv
# FOL_37_2_annotated.csv
# FOL_32_2_annotated.csv
# FOL_52_2_annotated.csv
# FOL_9_3_annotated.csv
# FOL_59_3_annotated.csv
# FOL_27_1_annotated.csv
# FOL_2_3_annotated.csv
# FOL_33_2_annotated.csv
# FOL_39_3_annotated.csv
# FOL_67_1_annotated.csv
# FOL_51_2_annotated.csv
# FOL_34_3_annotated.csv
# FOL_17_1_annotated.csv
# FOL_3_2_annotated.csv
# FOL_11_2_annotated.csv
# FOL_47_3_annotated.csv
# FOL_31_1_annotated.csv
# FOL_2_1_annotated.csv
# FOL_67_3_annotated.csv
# FOL_6_3_annotated.csv
# FOL_12_2_annotated.csv
# FOL_32_1_annotated.csv
# FOL_47_2_annotated.csv
# FOL_25_3_annotated.csv
# FOL_30_3_annotated.csv
# FOL_45_1_annotated.csv
# FOL_55_3_annotated.csv
# FOL_8_2_annotated.csv
# FOL_11_1_annotated.csv
# FOL_15_1_annotated.csv
# FOL_64_3_annotated.csv
# FOL_20_3_annotated.csv
# FOL_46_2_annotated.csv
# FOL_49_3_annotated.csv
# FOL_53_2_annotated.csv
# FOL_62_2_annotated.csv
# FOL_8_1_annotated.csv
# FOL_1_3_annotated.csv
# FOL_65_1_annotated.csv
# FOL_21_1_annotated.csv
# FOL_60_2_annotated.csv
# FOL_10_1_annotated.csv
# FOL_34_2_annotated.csv
# FOL_35_1_annotated.csv
# FOL_43_2_annotated.csv
# FOL_14_2_annotated.csv
# FOL_14_1_annotated.csv
# FOL_30_1_annotated.csv
# FOL_38_1_annotated.csv
# FOL_49_2_annotated.csv
# FOL_21_2_annotated.csv
# FOL_29_2_annotated.csv
# FOL_61_1_annotated.csv
# STU_45_3_annotated.csv
# STU_50_5_annotated.csv
# STU_36_5_annotated.csv
# STU_36_4_annotated.csv
# STU_43_4_annotated.csv
# STU_5_4_annotated.csv
# STU_64_3_annotated.csv
# STU_57_5_annotated.csv
# STU_34_4_annotated.csv
# STU_33_3_annotated.csv
# STU_37_4_annotated.csv
# STU_2_1_annotated.csv
# STU_52_4_annotated.csv
# STU_56_5_annotated.csv
# STU_9_5_annotated.csv
# STU_47_2_annotated.csv
# STU_1_5_annotated.csv
# STU_29_5_annotated.csv
# STU_23_3_annotated.csv
# STU_19_6_annotated.csv
# STU_29_6_annotated.csv
# STU_20_6_annotated.csv
# STU_2_5_annotated.csv
# STU_22_2_annotated.csv
# STU_7_1_annotated.csv
# STU_62_2_annotated.csv
# STU_41_2_annotated.csv
# STU_9_6_annotated.csv
# STU_25_1_annotated.csv
# STU_24_1_annotated.csv
# STU_11_2_annotated.csv
# STU_36_2_annotated.csv
# STU_10_3_annotated.csv
# STU_57_4_annotated.csv
# STU_60_6_annotated.csv
# STU_39_1_annotated.csv
# STU_10_6_annotated.csv
# STU_61_3_annotated.csv
# STU_32_1_annotated.csv
# STU_45_1_annotated.csv
# STU_43_3_annotated.csv
# STU_51_5_annotated.csv
# STU_42_5_annotated.csv
# STU_40_4_annotated.csv
# STU_54_2_annotated.csv
# STU_32_3_annotated.csv
# STU_43_5_annotated.csv
# STU_36_3_annotated.csv
# STU_35_3_annotated.csv
# STU_34_2_annotated.csv
# STU_67_1_annotated.csv
# STU_42_6_annotated.csv
# STU_34_5_annotated.csv
# STU_22_5_annotated.csv
# STU_21_3_annotated.csv
# STU_62_3_annotated.csv
# STU_49_1_annotated.csv
# STU_1_2_annotated.csv
# STU_45_6_annotated.csv
# STU_52_3_annotated.csv
# STU_61_6_annotated.csv
# STU_64_6_annotated.csv
# STU_41_6_annotated.csv
# STU_16_6_annotated.csv
# STU_60_4_annotated.csv
# STU_40_2_annotated.csv
# STU_44_1_annotated.csv
# STU_49_5_annotated.csv
# STU_22_4_annotated.csv
# STU_50_6_annotated.csv
# STU_23_4_annotated.csv
# STU_25_6_annotated.csv
# STU_12_5_annotated.csv
# STU_40_5_annotated.csv
# STU_63_3_annotated.csv
# STU_50_3_annotated.csv
# STU_12_4_annotated.csv
# STU_33_1_annotated.csv
# STU_28_5_annotated.csv
# STU_59_6_annotated.csv
# STU_27_5_annotated.csv
# STU_43_1_annotated.csv
# STU_18_1_annotated.csv
# STU_59_3_annotated.csv
# STU_11_6_annotated.csv
# STU_57_3_annotated.csv
# STU_55_2_annotated.csv
# STU_32_4_annotated.csv
# STU_63_4_annotated.csv
# STU_60_2_annotated.csv
# STU_22_6_annotated.csv
# STU_19_2_annotated.csv
# STU_46_1_annotated.csv
# STU_49_6_annotated.csv
# STU_49_4_annotated.csv
# STU_1_6_annotated.csv
# STU_7_3_annotated.csv
# STU_12_2_annotated.csv
# STU_67_3_annotated.csv
# STU_1_1_annotated.csv
# STU_41_1_annotated.csv
# STU_47_6_annotated.csv
# STU_53_6_annotated.csv
# STU_21_6_annotated.csv
# STU_23_2_annotated.csv
# STU_52_5_annotated.csv
# STU_44_3_annotated.csv
# STU_38_2_annotated.csv
# STU_48_4_annotated.csv
# STU_28_4_annotated.csv
# STU_37_6_annotated.csv
# STU_21_1_annotated.csv
# STU_44_4_annotated.csv
# STU_20_1_annotated.csv
# STU_58_2_annotated.csv
# STU_58_1_annotated.csv
# STU_26_5_annotated.csv
# STU_36_1_annotated.csv
# STU_3_2_annotated.csv
# STU_28_6_annotated.csv
# STU_6_2_annotated.csv
# STU_66_6_annotated.csv
# STU_33_6_annotated.csv
# STU_66_5_annotated.csv
# STU_6_3_annotated.csv
# STU_16_1_annotated.csv
# STU_64_1_annotated.csv
# STU_16_2_annotated.csv
# STU_61_4_annotated.csv
# STU_60_5_annotated.csv
# STU_59_2_annotated.csv
# STU_20_4_annotated.csv
# STU_7_5_annotated.csv
# STU_64_4_annotated.csv
# STU_47_3_annotated.csv
# STU_42_1_annotated.csv
# STU_11_4_annotated.csv
# STU_47_1_annotated.csv
# STU_26_2_annotated.csv
# STU_41_4_annotated.csv
# STU_21_2_annotated.csv
# STU_64_5_annotated.csv
# STU_29_2_annotated.csv
# STU_18_4_annotated.csv
# STU_4_5_annotated.csv
# STU_36_6_annotated.csv
# STU_27_2_annotated.csv
# STU_66_3_annotated.csv
# STU_60_3_annotated.csv
# STU_62_1_annotated.csv
# STU_44_2_annotated.csv
# STU_8_6_annotated.csv
# STU_44_5_annotated.csv
# STU_66_2_annotated.csv
# STU_10_5_annotated.csv
# STU_38_3_annotated.csv
# STU_57_1_annotated.csv
# STU_61_1_annotated.csv
# STU_42_2_annotated.csv
# STU_8_1_annotated.csv
# STU_66_4_annotated.csv
# STU_24_2_annotated.csv
# STU_7_4_annotated.csv
# STU_7_2_annotated.csv
# STU_48_6_annotated.csv
# STU_26_6_annotated.csv
# STU_25_5_annotated.csv
# STU_58_3_annotated.csv
# STU_22_3_annotated.csv
# STU_65_6_annotated.csv
# STU_4_2_annotated.csv
# STU_8_4_annotated.csv
# STU_61_5_annotated.csv
# STU_49_3_annotated.csv
# STU_56_3_annotated.csv
# STU_52_6_annotated.csv
# STU_8_2_annotated.csv
# STU_10_1_annotated.csv
# STU_33_5_annotated.csv
# STU_53_5_annotated.csv
# STU_34_6_annotated.csv
# STU_49_2_annotated.csv
# STU_45_2_annotated.csv
# STU_18_2_annotated.csv
# STU_67_5_annotated.csv
# STU_20_3_annotated.csv
# STU_5_6_annotated.csv
# STU_9_2_annotated.csv
# STU_67_6_annotated.csv
# STU_4_3_annotated.csv
# STU_53_2_annotated.csv
# STU_61_2_annotated.csv
# STU_58_6_annotated.csv
# STU_38_4_annotated.csv
# STU_55_3_annotated.csv
# STU_50_2_annotated.csv
# STU_59_4_annotated.csv
# STU_26_3_annotated.csv
# STU_12_3_annotated.csv
# STU_37_3_annotated.csv
# STU_41_3_annotated.csv
# STU_54_6_annotated.csv
# STU_35_5_annotated.csv
# STU_20_2_annotated.csv
# STU_4_1_annotated.csv
# STU_46_5_annotated.csv
# STU_41_5_annotated.csv
# STU_51_4_annotated.csv
# STU_46_6_annotated.csv
# STU_3_3_annotated.csv
# STU_51_3_annotated.csv
# STU_39_4_annotated.csv
# STU_22_1_annotated.csv
# STU_56_4_annotated.csv
# STU_12_6_annotated.csv
# STU_60_1_annotated.csv
# STU_33_4_annotated.csv
# STU_54_1_annotated.csv
# STU_65_3_annotated.csv
# STU_9_1_annotated.csv
# STU_56_2_annotated.csv
# STU_56_6_annotated.csv
# STU_27_4_annotated.csv
# STU_2_6_annotated.csv
# STU_55_6_annotated.csv
# STU_25_4_annotated.csv
# STU_32_6_annotated.csv
# STU_38_5_annotated.csv
# STU_6_4_annotated.csv
# STU_63_1_annotated.csv
# STU_51_1_annotated.csv
# STU_59_1_annotated.csv
# STU_21_4_annotated.csv
# STU_4_6_annotated.csv
# STU_50_4_annotated.csv
# STU_34_1_annotated.csv
# STU_16_4_annotated.csv
# STU_44_6_annotated.csv
# STU_33_2_annotated.csv
# STU_26_4_annotated.csv
# STU_35_4_annotated.csv
# STU_26_1_annotated.csv
# STU_5_2_annotated.csv
# STU_28_2_annotated.csv
# STU_2_3_annotated.csv
# STU_19_5_annotated.csv
# STU_45_4_annotated.csv
# STU_62_5_annotated.csv
# STU_23_5_annotated.csv
# STU_54_3_annotated.csv
# STU_52_2_annotated.csv
# STU_40_1_annotated.csv
# STU_5_3_annotated.csv
# STU_42_3_annotated.csv
# STU_11_1_annotated.csv
# STU_39_5_annotated.csv
# STU_18_5_annotated.csv
# STU_10_4_annotated.csv
# STU_2_2_annotated.csv
# STU_53_3_annotated.csv
# STU_53_4_annotated.csv
# STU_3_4_annotated.csv
# STU_9_3_annotated.csv
# STU_6_6_annotated.csv
# STU_21_5_annotated.csv
# STU_63_2_annotated.csv
# STU_67_4_annotated.csv
# STU_16_3_annotated.csv
# STU_56_1_annotated.csv
# STU_8_5_annotated.csv
# STU_45_5_annotated.csv
# STU_62_6_annotated.csv
# STU_55_4_annotated.csv
# STU_42_4_annotated.csv
# STU_24_5_annotated.csv
# STU_19_1_annotated.csv
# STU_46_2_annotated.csv
# STU_38_1_annotated.csv
# STU_24_6_annotated.csv
# STU_46_3_annotated.csv
# STU_66_1_annotated.csv
# STU_37_2_annotated.csv
# STU_7_6_annotated.csv
# STU_25_3_annotated.csv
# STU_20_5_annotated.csv
# STU_2_4_annotated.csv
# STU_23_1_annotated.csv
# STU_51_6_annotated.csv
# STU_55_1_annotated.csv
# STU_32_2_annotated.csv
# STU_19_3_annotated.csv
# STU_18_3_annotated.csv
# STU_48_5_annotated.csv
# STU_25_2_annotated.csv
# STU_67_2_annotated.csv
# STU_64_2_annotated.csv
# STU_39_3_annotated.csv
# STU_63_6_annotated.csv
# STU_29_1_annotated.csv
# STU_57_6_annotated.csv
# STU_51_2_annotated.csv
# STU_29_3_annotated.csv
# STU_35_6_annotated.csv
# STU_3_5_annotated.csv
# STU_37_5_annotated.csv
# STU_24_3_annotated.csv
# STU_52_1_annotated.csv
# STU_23_6_annotated.csv
# STU_65_2_annotated.csv
# STU_47_4_annotated.csv
# STU_65_1_annotated.csv
# STU_12_1_annotated.csv
# STU_48_2_annotated.csv
# STU_5_5_annotated.csv
# STU_43_2_annotated.csv
# STU_57_2_annotated.csv
# STU_32_5_annotated.csv
# STU_34_3_annotated.csv
# STU_5_1_annotated.csv
# STU_37_1_annotated.csv
# STU_47_5_annotated.csv
# STU_19_4_annotated.csv
# STU_59_5_annotated.csv
# STU_18_6_annotated.csv
# STU_3_6_annotated.csv
# STU_43_6_annotated.csv
# STU_27_1_annotated.csv
# STU_65_4_annotated.csv
# STU_3_1_annotated.csv
# STU_1_4_annotated.csv
# STU_9_4_annotated.csv
# STU_35_2_annotated.csv
# STU_11_5_annotated.csv
# STU_1_3_annotated.csv
# STU_24_4_annotated.csv
# STU_40_3_annotated.csv
# STU_54_4_annotated.csv
# STU_38_6_annotated.csv
# STU_28_1_annotated.csv
# STU_55_5_annotated.csv
# STU_50_1_annotated.csv
# STU_35_1_annotated.csv
# STU_16_5_annotated.csv
# STU_46_4_annotated.csv
# STU_48_3_annotated.csv
# STU_53_1_annotated.csv
# STU_58_5_annotated.csv
# STU_6_1_annotated.csv
# STU_63_5_annotated.csv
# STU_11_3_annotated.csv
# STU_58_4_annotated.csv
# STU_39_2_annotated.csv
# STU_40_6_annotated.csv
# STU_54_5_annotated.csv
# STU_8_3_annotated.csv
# STU_62_4_annotated.csv
# STU_65_5_annotated.csv
# STU_27_6_annotated.csv
# STU_39_6_annotated.csv
# STU_6_5_annotated.csv
# STU_29_4_annotated.csv
# STU_4_4_annotated.csv
# STU_48_1_annotated.csv
# STU_28_3_annotated.csv
# SDL_17_2_annotated.csv
# SDL_19_3_annotated.csv
# SDL_55_2_annotated.csv
# SDL_67_3_annotated.csv
# SDL_23_2_annotated.csv
# SDL_17_1_annotated.csv
# SDL_59_3_annotated.csv
# SDL_36_2_annotated.csv
# SDL_18_1_annotated.csv
# SDL_18_2_annotated.csv
# SDL_16_2_annotated.csv
# SDL_38_3_annotated.csv
# SDL_20_1_annotated.csv
# SDL_61_2_annotated.csv
# SDL_57_3_annotated.csv
# SDL_65_1_annotated.csv
# SDL_11_3_annotated.csv
# SDL_66_3_annotated.csv
# SDL_13_3_annotated.csv
# SDL_19_2_annotated.csv
# SDL_65_2_annotated.csv
# SDL_1_3_annotated.csv
# SDL_62_1_annotated.csv
# SDL_30_2_annotated.csv
# SDL_66_1_annotated.csv
# SDL_48_1_annotated.csv
# SDL_1_2_annotated.csv
# SDL_47_1_annotated.csv
# SDL_60_3_annotated.csv
# SDL_4_3_annotated.csv
# SDL_67_2_annotated.csv
# SDL_29_3_annotated.csv
# SDL_44_2_annotated.csv
# SDL_30_1_annotated.csv
# SDL_32_1_annotated.csv
# SDL_22_2_annotated.csv
# SDL_16_3_annotated.csv
# SDL_28_1_annotated.csv
# SDL_61_1_annotated.csv
# SDL_11_1_annotated.csv
# SDL_66_2_annotated.csv
# SDL_14_1_annotated.csv
# SDL_21_2_annotated.csv
# SDL_33_3_annotated.csv
# SDL_58_3_annotated.csv
# SDL_15_2_annotated.csv
# SDL_55_1_annotated.csv
# SDL_8_3_annotated.csv
# SDL_67_1_annotated.csv
# SDL_26_1_annotated.csv
# SDL_44_1_annotated.csv
# SDL_62_3_annotated.csv
# SDL_63_3_annotated.csv
# SDL_25_3_annotated.csv
# SDL_60_1_annotated.csv
# SDL_3_1_annotated.csv
# SDL_13_1_annotated.csv
# SDL_64_3_annotated.csv
# SDL_43_3_annotated.csv
# SDL_32_2_annotated.csv
# SDL_5_3_annotated.csv
# SDL_26_3_annotated.csv
# SDL_6_3_annotated.csv
# SDL_54_2_annotated.csv
# SDL_42_1_annotated.csv
# SDL_63_2_annotated.csv
# SDL_53_1_annotated.csv
# SDL_51_2_annotated.csv
# SDL_46_1_annotated.csv
# SDL_15_3_annotated.csv
# SDL_12_2_annotated.csv
# SDL_4_2_annotated.csv
# SDL_48_2_annotated.csv
# SDL_28_3_annotated.csv
# SDL_54_1_annotated.csv
# SDL_46_3_annotated.csv
# SDL_42_3_annotated.csv
# SDL_13_2_annotated.csv
# SDL_56_1_annotated.csv
# SDL_5_2_annotated.csv
# SDL_61_3_annotated.csv
# SDL_18_3_annotated.csv
# SDL_10_3_annotated.csv
# SDL_33_1_annotated.csv
# SDL_52_3_annotated.csv
# SDL_20_2_annotated.csv
# SDL_31_2_annotated.csv
# SDL_40_2_annotated.csv
# SDL_57_2_annotated.csv
# SDL_37_3_annotated.csv
# SDL_31_3_annotated.csv
# SDL_29_1_annotated.csv
# SDL_10_2_annotated.csv
# SDL_15_1_annotated.csv
# SDL_8_1_annotated.csv
# SDL_58_2_annotated.csv
# SDL_42_2_annotated.csv
# SDL_45_3_annotated.csv
# SDL_31_1_annotated.csv
# SDL_27_2_annotated.csv
# SDL_1_1_annotated.csv
# SDL_38_1_annotated.csv
# SDL_54_3_annotated.csv
# SDL_28_2_annotated.csv
# SDL_57_1_annotated.csv
# SDL_7_1_annotated.csv
# SDL_5_1_annotated.csv
# SDL_33_2_annotated.csv
# SDL_25_1_annotated.csv
# SDL_59_1_annotated.csv
# SDL_47_3_annotated.csv
# SDL_2_1_annotated.csv
# SDL_32_3_annotated.csv
# SDL_20_3_annotated.csv
# SDL_14_2_annotated.csv
# SDL_21_3_annotated.csv
# SDL_53_3_annotated.csv
# SDL_34_2_annotated.csv
# SDL_23_3_annotated.csv
# SDL_60_2_annotated.csv
# SDL_19_1_annotated.csv
# SDL_11_2_annotated.csv
# SDL_27_1_annotated.csv
# SDL_62_2_annotated.csv
# SDL_35_2_annotated.csv
# SDL_39_3_annotated.csv
# SDL_12_3_annotated.csv
# SDL_51_1_annotated.csv
# SDL_2_3_annotated.csv
# SDL_22_1_annotated.csv
# SDL_49_3_annotated.csv
# SDL_17_3_annotated.csv
# SDL_9_1_annotated.csv
# SDL_64_1_annotated.csv
# SDL_35_1_annotated.csv
# SDL_34_3_annotated.csv
# SDL_10_1_annotated.csv
# SDL_22_3_annotated.csv
# SDL_2_2_annotated.csv
# SDL_43_1_annotated.csv
# SDL_7_3_annotated.csv
# SDL_49_2_annotated.csv
# SDL_29_2_annotated.csv
# SDL_53_2_annotated.csv
# SDL_43_2_annotated.csv
# SDL_44_3_annotated.csv
# SDL_47_2_annotated.csv
# SDL_51_3_annotated.csv
# SDL_36_1_annotated.csv
# SDL_16_1_annotated.csv
# SDL_56_2_annotated.csv
# SDL_6_1_annotated.csv
# SDL_25_2_annotated.csv
# SDL_59_2_annotated.csv
# SDL_6_2_annotated.csv
# SDL_49_1_annotated.csv
# SDL_52_2_annotated.csv
# SDL_39_1_annotated.csv
# SDL_55_3_annotated.csv
# SDL_48_3_annotated.csv
# SDL_14_3_annotated.csv
# SDL_37_2_annotated.csv
# SDL_46_2_annotated.csv
# SDL_23_1_annotated.csv
# SDL_40_1_annotated.csv
# SDL_52_1_annotated.csv
# SDL_3_3_annotated.csv
# SDL_27_3_annotated.csv
# SDL_35_3_annotated.csv
# SDL_63_1_annotated.csv
# SDL_37_1_annotated.csv
# SDL_45_1_annotated.csv
# SDL_9_3_annotated.csv
# SDL_26_2_annotated.csv
# SDL_8_2_annotated.csv
# SDL_45_2_annotated.csv
# SDL_64_2_annotated.csv
# SDL_34_1_annotated.csv
# SDL_38_2_annotated.csv
# SDL_65_3_annotated.csv
# SDL_3_2_annotated.csv
# SDL_36_3_annotated.csv
# SDL_30_3_annotated.csv
# SDL_56_3_annotated.csv
# SDL_58_1_annotated.csv
# SDL_21_1_annotated.csv
# SDL_40_3_annotated.csv
# SDL_12_1_annotated.csv
# SDL_7_2_annotated.csv
# SDL_9_2_annotated.csv
# SDL_39_2_annotated.csv
# SDL_4_1_annotated.csv
# SIT_64_1_annotated.csv
# SIT_12_1_annotated.csv
# SIT_3_1_annotated.csv
# SIT_2_1_annotated.csv
# SIT_5_1_annotated.csv
# SIT_6_1_annotated.csv
# SIT_61_1_annotated.csv
# SIT_20_1_annotated.csv
# SIT_66_1_annotated.csv
# SIT_1_1_annotated.csv
# SIT_63_1_annotated.csv
# SIT_60_1_annotated.csv
# SIT_67_1_annotated.csv
# SIT_53_1_annotated.csv
# SIT_65_1_annotated.csv
# SIT_58_1_annotated.csv
# SIT_59_1_annotated.csv
# SIT_62_1_annotated.csv
# SIT_45_1_annotated.csv
# FKL_7_3_annotated.csv
# FKL_34_1_annotated.csv
# FKL_36_3_annotated.csv
# FKL_58_3_annotated.csv
# FKL_66_2_annotated.csv
# FKL_46_3_annotated.csv
# FKL_9_3_annotated.csv
# FKL_39_3_annotated.csv
# FKL_10_1_annotated.csv
# FKL_47_2_annotated.csv
# FKL_61_3_annotated.csv
# FKL_29_1_annotated.csv
# FKL_4_1_annotated.csv
# FKL_33_2_annotated.csv
# FKL_65_1_annotated.csv
# FKL_62_2_annotated.csv
# FKL_23_3_annotated.csv
# FKL_65_2_annotated.csv
# FKL_55_2_annotated.csv
# FKL_12_3_annotated.csv
# FKL_23_1_annotated.csv
# FKL_27_3_annotated.csv
# FKL_1_2_annotated.csv
# FKL_2_1_annotated.csv
# FKL_13_1_annotated.csv
# FKL_21_1_annotated.csv
# FKL_39_2_annotated.csv
# FKL_2_2_annotated.csv
# FKL_59_2_annotated.csv
# FKL_13_2_annotated.csv
# FKL_9_2_annotated.csv
# FKL_48_3_annotated.csv
# FKL_26_3_annotated.csv
# FKL_30_3_annotated.csv
# FKL_28_2_annotated.csv
# FKL_63_1_annotated.csv
# FKL_25_1_annotated.csv
# FKL_43_3_annotated.csv
# FKL_66_1_annotated.csv
# FKL_26_2_annotated.csv
# FKL_64_1_annotated.csv
# FKL_15_2_annotated.csv
# FKL_43_1_annotated.csv
# FKL_27_2_annotated.csv
# FKL_45_2_annotated.csv
# FKL_16_3_annotated.csv
# FKL_13_3_annotated.csv
# FKL_21_3_annotated.csv
# FKL_36_2_annotated.csv
# FKL_29_3_annotated.csv
# FKL_11_3_annotated.csv
# FKL_42_2_annotated.csv
# FKL_4_2_annotated.csv
# FKL_6_2_annotated.csv
# FKL_58_2_annotated.csv
# FKL_37_2_annotated.csv
# FKL_57_1_annotated.csv
# FKL_53_3_annotated.csv
# FKL_5_1_annotated.csv
# FKL_3_2_annotated.csv
# FKL_15_1_annotated.csv
# FKL_40_2_annotated.csv
# FKL_35_2_annotated.csv
# FKL_26_1_annotated.csv
# FKL_4_3_annotated.csv
# FKL_20_3_annotated.csv
# FKL_30_2_annotated.csv
# FKL_22_1_annotated.csv
# FKL_1_1_annotated.csv
# FKL_34_2_annotated.csv
# FKL_48_2_annotated.csv
# FKL_33_3_annotated.csv
# FKL_6_3_annotated.csv
# FKL_31_3_annotated.csv
# FKL_57_2_annotated.csv
# FKL_10_2_annotated.csv
# FKL_67_3_annotated.csv
# FKL_16_1_annotated.csv
# FKL_32_3_annotated.csv
# FKL_35_1_annotated.csv
# FKL_53_2_annotated.csv
# FKL_56_2_annotated.csv
# FKL_31_2_annotated.csv
# FKL_36_1_annotated.csv
# FKL_30_1_annotated.csv
# FKL_59_1_annotated.csv
# FKL_62_3_annotated.csv
# FKL_49_1_annotated.csv
# FKL_33_1_annotated.csv
# FKL_18_3_annotated.csv
# FKL_38_1_annotated.csv
# FKL_44_1_annotated.csv
# FKL_27_1_annotated.csv
# FKL_19_1_annotated.csv
# FKL_19_2_annotated.csv
# FKL_12_2_annotated.csv
# FKL_40_1_annotated.csv
# FKL_47_1_annotated.csv
# FKL_17_2_annotated.csv
# FKL_38_2_annotated.csv
# FKL_55_1_annotated.csv
# FKL_3_1_annotated.csv
# FKL_21_2_annotated.csv
# FKL_14_1_annotated.csv
# FKL_52_2_annotated.csv
# FKL_47_3_annotated.csv
# FKL_37_1_annotated.csv
# FKL_64_3_annotated.csv
# FKL_54_3_annotated.csv
# FKL_58_1_annotated.csv
# FKL_56_1_annotated.csv
# FKL_59_3_annotated.csv
# FKL_63_3_annotated.csv
# FKL_45_1_annotated.csv
# FKL_23_2_annotated.csv
# FKL_56_3_annotated.csv
# FKL_61_2_annotated.csv
# FKL_32_1_annotated.csv
# FKL_5_2_annotated.csv
# FKL_29_2_annotated.csv
# FKL_44_3_annotated.csv
# FKL_44_2_annotated.csv
# FKL_19_3_annotated.csv
# FKL_67_2_annotated.csv
# FKL_52_1_annotated.csv
# FKL_7_2_annotated.csv
# FKL_9_1_annotated.csv
# FKL_46_1_annotated.csv
# FKL_6_1_annotated.csv
# FKL_51_3_annotated.csv
# FKL_14_2_annotated.csv
# FKL_15_3_annotated.csv
# FKL_8_1_annotated.csv
# FKL_57_3_annotated.csv
# FKL_17_1_annotated.csv
# FKL_14_3_annotated.csv
# FKL_60_3_annotated.csv
# FKL_64_2_annotated.csv
# FKL_28_1_annotated.csv
# FKL_63_2_annotated.csv
# FKL_34_3_annotated.csv
# FKL_45_3_annotated.csv
# FKL_66_3_annotated.csv
# FKL_43_2_annotated.csv
# FKL_52_3_annotated.csv
# FKL_12_1_annotated.csv
# FKL_8_3_annotated.csv
# FKL_25_2_annotated.csv
# FKL_67_1_annotated.csv
# FKL_40_3_annotated.csv
# FKL_62_1_annotated.csv
# FKL_54_2_annotated.csv
# FKL_65_3_annotated.csv
# FKL_38_3_annotated.csv
# FKL_60_1_annotated.csv
# FKL_7_1_annotated.csv
# FKL_46_2_annotated.csv
# FKL_61_1_annotated.csv
# FKL_32_2_annotated.csv
# FKL_31_1_annotated.csv
# FKL_2_3_annotated.csv
# FKL_10_3_annotated.csv
# FKL_54_1_annotated.csv
# FKL_11_1_annotated.csv
# FKL_42_3_annotated.csv
# FKL_16_2_annotated.csv
# FKL_17_3_annotated.csv
# FKL_42_1_annotated.csv
# FKL_39_1_annotated.csv
# FKL_20_2_annotated.csv
# FKL_18_2_annotated.csv
# FKL_11_2_annotated.csv
# FKL_22_2_annotated.csv
# FKL_1_3_annotated.csv
# FKL_20_1_annotated.csv
# FKL_8_2_annotated.csv
# FKL_5_3_annotated.csv
# FKL_22_3_annotated.csv
# FKL_18_1_annotated.csv
# FKL_37_3_annotated.csv
# FKL_53_1_annotated.csv
# FKL_55_3_annotated.csv
# FKL_51_1_annotated.csv
# FKL_60_2_annotated.csv
# FKL_49_3_annotated.csv
# FKL_49_2_annotated.csv
# FKL_48_1_annotated.csv
# FKL_35_3_annotated.csv
# FKL_51_2_annotated.csv
# FKL_28_3_annotated.csv
# FKL_3_3_annotated.csv
# FKL_25_3_annotated.csv
# WAL_11_1_annotated.csv
# WAL_44_1_annotated.csv
# WAL_60_1_annotated.csv
# WAL_25_1_annotated.csv
# WAL_1_1_annotated.csv
# WAL_61_1_annotated.csv
# WAL_2_1_annotated.csv
# WAL_39_1_annotated.csv
# WAL_64_1_annotated.csv
# WAL_49_1_annotated.csv
# WAL_52_1_annotated.csv
# WAL_51_1_annotated.csv
# WAL_57_1_annotated.csv
# WAL_8_1_annotated.csv
# WAL_21_1_annotated.csv
# WAL_42_1_annotated.csv
# WAL_7_1_annotated.csv
# WAL_32_1_annotated.csv
# WAL_43_1_annotated.csv
# WAL_34_1_annotated.csv
# WAL_37_1_annotated.csv
# WAL_20_1_annotated.csv
# WAL_9_1_annotated.csv
# WAL_48_1_annotated.csv
# WAL_46_1_annotated.csv
# WAL_63_1_annotated.csv
# WAL_3_1_annotated.csv
# WAL_62_1_annotated.csv
# WAL_12_1_annotated.csv
# WAL_19_1_annotated.csv
# WAL_53_1_annotated.csv
# WAL_58_1_annotated.csv
# WAL_47_1_annotated.csv
# WAL_27_1_annotated.csv
# WAL_35_1_annotated.csv
# WAL_24_1_annotated.csv
# WAL_22_1_annotated.csv
# WAL_6_1_annotated.csv
# WAL_26_1_annotated.csv
# WAL_23_1_annotated.csv
# WAL_5_1_annotated.csv
# WAL_56_1_annotated.csv
# WAL_4_1_annotated.csv
# WAL_45_1_annotated.csv
# WAL_16_1_annotated.csv
# WAL_40_1_annotated.csv
# WAL_65_1_annotated.csv
# WAL_38_1_annotated.csv
# WAL_50_1_annotated.csv
# WAL_59_1_annotated.csv
# WAL_10_1_annotated.csv
# WAL_55_1_annotated.csv
# WAL_18_1_annotated.csv
# WAL_54_1_annotated.csv
# WAL_29_1_annotated.csv
# WAL_67_1_annotated.csv
# WAL_41_1_annotated.csv
# WAL_66_1_annotated.csv
# WAL_36_1_annotated.csv
# WAL_28_1_annotated.csv
# WAL_33_1_annotated.csv
# STN_8_4_annotated.csv
# STN_34_2_annotated.csv
# STN_40_2_annotated.csv
# STN_45_6_annotated.csv
# STN_20_1_annotated.csv
# STN_5_5_annotated.csv
# STN_65_1_annotated.csv
# STN_18_1_annotated.csv
# STN_4_3_annotated.csv
# STN_65_3_annotated.csv
# STN_5_1_annotated.csv
# STN_56_2_annotated.csv
# STN_37_1_annotated.csv
# STN_23_4_annotated.csv
# STN_39_2_annotated.csv
# STN_20_3_annotated.csv
# STN_67_5_annotated.csv
# STN_29_1_annotated.csv
# STN_57_5_annotated.csv
# STN_48_2_annotated.csv
# STN_26_2_annotated.csv
# STN_51_2_annotated.csv
# STN_1_4_annotated.csv
# STN_4_5_annotated.csv
# STN_60_1_annotated.csv
# STN_29_4_annotated.csv
# STN_18_4_annotated.csv
# STN_38_5_annotated.csv
# STN_24_2_annotated.csv
# STN_45_3_annotated.csv
# STN_58_2_annotated.csv
# STN_27_2_annotated.csv
# STN_62_5_annotated.csv
# STN_9_4_annotated.csv
# STN_50_6_annotated.csv
# STN_4_2_annotated.csv
# STN_51_5_annotated.csv
# STN_40_6_annotated.csv
# STN_52_6_annotated.csv
# STN_48_4_annotated.csv
# STN_4_1_annotated.csv
# STN_23_1_annotated.csv
# STN_25_6_annotated.csv
# STN_34_1_annotated.csv
# STN_24_5_annotated.csv
# STN_65_5_annotated.csv
# STN_22_5_annotated.csv
# STN_56_1_annotated.csv
# STN_50_5_annotated.csv
# STN_3_2_annotated.csv
# STN_32_1_annotated.csv
# STN_16_4_annotated.csv
# STN_21_5_annotated.csv
# STN_52_3_annotated.csv
# STN_53_3_annotated.csv
# STN_39_4_annotated.csv
# STN_39_5_annotated.csv
# STN_59_2_annotated.csv
# STN_33_3_annotated.csv
# STN_23_5_annotated.csv
# STN_3_1_annotated.csv
# STN_24_1_annotated.csv
# STN_16_1_annotated.csv
# STN_36_2_annotated.csv
# STN_56_5_annotated.csv
# STN_2_5_annotated.csv
# STN_54_4_annotated.csv
# STN_6_1_annotated.csv
# STN_60_5_annotated.csv
# STN_3_6_annotated.csv
# STN_54_5_annotated.csv
# STN_2_4_annotated.csv
# STN_10_3_annotated.csv
# STN_35_1_annotated.csv
# STN_12_4_annotated.csv
# STN_35_6_annotated.csv
# STN_28_1_annotated.csv
# STN_23_2_annotated.csv
# STN_35_5_annotated.csv
# STN_33_2_annotated.csv
# STN_7_1_annotated.csv
# STN_58_3_annotated.csv
# STN_41_3_annotated.csv
# STN_1_1_annotated.csv
# STN_65_6_annotated.csv
# STN_63_6_annotated.csv
# STN_10_5_annotated.csv
# STN_56_6_annotated.csv
# STN_26_6_annotated.csv
# STN_39_1_annotated.csv
# STN_63_5_annotated.csv
# STN_5_2_annotated.csv
# STN_50_3_annotated.csv
# STN_6_6_annotated.csv
# STN_62_3_annotated.csv
# STN_25_1_annotated.csv
# STN_10_1_annotated.csv
# STN_37_6_annotated.csv
# STN_55_6_annotated.csv
# STN_54_1_annotated.csv
# STN_9_3_annotated.csv
# STN_36_3_annotated.csv
# STN_61_5_annotated.csv
# STN_49_5_annotated.csv
# STN_49_2_annotated.csv
# STN_45_5_annotated.csv
# STN_29_3_annotated.csv
# STN_23_3_annotated.csv
# STN_52_5_annotated.csv
# STN_11_5_annotated.csv
# STN_45_4_annotated.csv
# STN_66_4_annotated.csv
# STN_51_3_annotated.csv
# STN_52_1_annotated.csv
# STN_12_5_annotated.csv
# STN_53_6_annotated.csv
# STN_7_5_annotated.csv
# STN_50_1_annotated.csv
# STN_41_5_annotated.csv
# STN_37_5_annotated.csv
# STN_26_3_annotated.csv
# STN_62_6_annotated.csv
# STN_55_2_annotated.csv
# STN_29_5_annotated.csv
# STN_40_3_annotated.csv
# STN_22_3_annotated.csv
# STN_8_2_annotated.csv
# STN_57_4_annotated.csv
# STN_20_5_annotated.csv
# STN_2_3_annotated.csv
# STN_27_6_annotated.csv
# STN_52_2_annotated.csv
# STN_41_4_annotated.csv
# STN_57_6_annotated.csv
# STN_50_4_annotated.csv
# STN_19_5_annotated.csv
# STN_10_6_annotated.csv
# STN_33_4_annotated.csv
# STN_48_3_annotated.csv
# STN_1_3_annotated.csv
# STN_43_4_annotated.csv
# STN_42_6_annotated.csv
# STN_67_6_annotated.csv
# STN_66_3_annotated.csv
# STN_23_6_annotated.csv
# STN_12_3_annotated.csv
# STN_36_5_annotated.csv
# STN_62_2_annotated.csv
# STN_22_6_annotated.csv
# STN_20_2_annotated.csv
# STN_37_2_annotated.csv
# STN_32_5_annotated.csv
# STN_12_2_annotated.csv
# STN_41_6_annotated.csv
# STN_43_5_annotated.csv
# STN_9_6_annotated.csv
# STN_25_4_annotated.csv
# STN_55_4_annotated.csv
# STN_9_2_annotated.csv
# STN_61_1_annotated.csv
# STN_36_1_annotated.csv
# STN_20_6_annotated.csv
# STN_65_4_annotated.csv
# STN_51_4_annotated.csv
# STN_25_5_annotated.csv
# STN_46_5_annotated.csv
# STN_58_1_annotated.csv
# STN_41_1_annotated.csv
# STN_8_3_annotated.csv
# STN_1_5_annotated.csv
# STN_6_3_annotated.csv
# STN_11_1_annotated.csv
# STN_32_6_annotated.csv
# STN_1_6_annotated.csv
# STN_52_4_annotated.csv
# STN_36_4_annotated.csv
# STN_61_6_annotated.csv
# STN_35_4_annotated.csv
# STN_35_2_annotated.csv
# STN_18_5_annotated.csv
# STN_29_6_annotated.csv
# STN_40_5_annotated.csv
# STN_42_2_annotated.csv
# STN_25_3_annotated.csv
# STN_16_5_annotated.csv
# STN_51_6_annotated.csv
# STN_51_1_annotated.csv
# STN_26_1_annotated.csv
# STN_66_6_annotated.csv
# STN_16_6_annotated.csv
# STN_55_5_annotated.csv
# STN_12_6_annotated.csv
# STN_62_4_annotated.csv
# STN_63_4_annotated.csv
# STN_38_3_annotated.csv
# STN_47_6_annotated.csv
# STN_46_6_annotated.csv
# STN_29_2_annotated.csv
# STN_28_6_annotated.csv
# STN_49_6_annotated.csv
# STN_18_6_annotated.csv
# STN_49_3_annotated.csv
# STN_5_6_annotated.csv
# STN_12_1_annotated.csv
# STN_21_4_annotated.csv
# STN_46_2_annotated.csv
# STN_28_3_annotated.csv
# STN_66_5_annotated.csv
# STN_58_5_annotated.csv
# STN_6_5_annotated.csv
# STN_65_2_annotated.csv
# STN_27_5_annotated.csv
# STN_24_3_annotated.csv
# STN_67_1_annotated.csv
# STN_3_4_annotated.csv
# STN_43_3_annotated.csv
# STN_50_2_annotated.csv
# STN_41_2_annotated.csv
# STN_3_5_annotated.csv
# STN_19_1_annotated.csv
# STN_58_6_annotated.csv
# STN_46_4_annotated.csv
# STN_22_2_annotated.csv
# STN_54_3_annotated.csv
# STN_26_4_annotated.csv
# STN_9_5_annotated.csv
# STN_61_2_annotated.csv
# STN_47_5_annotated.csv
# STN_21_1_annotated.csv
# STN_44_6_annotated.csv
# STN_43_6_annotated.csv
# STN_20_4_annotated.csv
# STN_27_4_annotated.csv
# STN_64_2_annotated.csv
# STN_38_6_annotated.csv
# STN_57_1_annotated.csv
# STN_39_3_annotated.csv
# STN_64_1_annotated.csv
# STN_48_6_annotated.csv
# STN_2_2_annotated.csv
# STN_11_6_annotated.csv
# STN_28_4_annotated.csv
# STN_61_4_annotated.csv
# STN_66_2_annotated.csv
# STN_37_4_annotated.csv
# STN_21_2_annotated.csv
# STN_48_1_annotated.csv
# STN_35_3_annotated.csv
# STN_60_3_annotated.csv
# STN_25_2_annotated.csv
# STN_56_3_annotated.csv
# STN_34_4_annotated.csv
# STN_47_2_annotated.csv
# STN_38_4_annotated.csv
# STN_18_2_annotated.csv
# STN_56_4_annotated.csv
# STN_42_3_annotated.csv
# STN_40_4_annotated.csv
# STN_9_1_annotated.csv
# STN_61_3_annotated.csv
# STN_40_1_annotated.csv
# STN_10_4_annotated.csv
# STN_24_6_annotated.csv
# STN_67_4_annotated.csv
# STN_5_4_annotated.csv
# STN_34_3_annotated.csv
# STN_44_5_annotated.csv
# STN_57_3_annotated.csv
# STN_63_3_annotated.csv
# STN_47_3_annotated.csv
# STN_60_6_annotated.csv
# STN_27_1_annotated.csv
# STN_45_2_annotated.csv
# STN_4_6_annotated.csv
# STN_46_1_annotated.csv
# STN_47_1_annotated.csv
# STN_3_3_annotated.csv
# STN_26_5_annotated.csv
# STN_1_2_annotated.csv
# STN_33_5_annotated.csv
# STN_7_4_annotated.csv
# STN_63_1_annotated.csv
# STN_60_2_annotated.csv
# STN_34_5_annotated.csv
# STN_5_3_annotated.csv
# STN_63_2_annotated.csv
# STN_59_6_annotated.csv
# STN_54_6_annotated.csv
# STN_42_4_annotated.csv
# STN_7_6_annotated.csv
# STN_44_4_annotated.csv
# STN_28_5_annotated.csv
# STN_49_4_annotated.csv
# STN_53_5_annotated.csv
# STN_49_1_annotated.csv
# STN_11_2_annotated.csv
# STN_8_5_annotated.csv
# STN_32_3_annotated.csv
# STN_38_2_annotated.csv
# STN_64_4_annotated.csv
# STN_53_1_annotated.csv
# STN_55_1_annotated.csv
# STN_58_4_annotated.csv
# STN_43_2_annotated.csv
# STN_24_4_annotated.csv
# STN_33_1_annotated.csv
# STN_59_3_annotated.csv
# STN_8_6_annotated.csv
# STN_19_4_annotated.csv
# STN_36_6_annotated.csv
# STN_59_4_annotated.csv
# STN_64_5_annotated.csv
# STN_66_1_annotated.csv
# STN_19_6_annotated.csv
# STN_48_5_annotated.csv
# STN_7_2_annotated.csv
# STN_21_3_annotated.csv
# STN_55_3_annotated.csv
# STN_2_6_annotated.csv
# STN_44_2_annotated.csv
# STN_57_2_annotated.csv
# STN_54_2_annotated.csv
# STN_59_1_annotated.csv
# STN_2_1_annotated.csv
# STN_39_6_annotated.csv
# STN_37_3_annotated.csv
# STN_42_5_annotated.csv
# STN_64_6_annotated.csv
# STN_60_4_annotated.csv
# STN_22_4_annotated.csv
# STN_53_4_annotated.csv
# STN_67_2_annotated.csv
# STN_8_1_annotated.csv
# STN_34_6_annotated.csv
# STN_28_2_annotated.csv
# STN_11_4_annotated.csv
# STN_46_3_annotated.csv
# STN_44_3_annotated.csv
# STN_32_2_annotated.csv
# STN_47_4_annotated.csv
# STN_64_3_annotated.csv
# STN_7_3_annotated.csv
# STN_33_6_annotated.csv
# STN_19_2_annotated.csv
# STN_11_3_annotated.csv
# STN_32_4_annotated.csv
# STN_16_2_annotated.csv
# STN_21_6_annotated.csv
# STN_38_1_annotated.csv
# STN_62_1_annotated.csv
# STN_18_3_annotated.csv
# STN_19_3_annotated.csv
# STN_53_2_annotated.csv
# STN_44_1_annotated.csv
# STN_22_1_annotated.csv
# STN_10_2_annotated.csv
# STN_59_5_annotated.csv
# STN_45_1_annotated.csv
# STN_67_3_annotated.csv
# STN_43_1_annotated.csv
# STN_42_1_annotated.csv
# STN_6_2_annotated.csv
# STN_4_4_annotated.csv
# STN_16_3_annotated.csv
# STN_6_4_annotated.csv
# STD_23_1_annotated.csv
# STD_43_1_annotated.csv
# STD_55_1_annotated.csv
# STD_63_1_annotated.csv
# STD_49_1_annotated.csv
# STD_33_1_annotated.csv
# STD_3_1_annotated.csv
# STD_39_1_annotated.csv
# STD_56_1_annotated.csv
# STD_58_1_annotated.csv
# STD_8_1_annotated.csv
# STD_22_1_annotated.csv
# STD_57_1_annotated.csv
# STD_61_1_annotated.csv
# STD_29_1_annotated.csv
# STD_4_1_annotated.csv
# STD_41_1_annotated.csv
# STD_35_1_annotated.csv
# STD_64_1_annotated.csv
# STD_19_1_annotated.csv
# STD_1_1_annotated.csv
# STD_47_1_annotated.csv
# STD_9_1_annotated.csv
# STD_65_1_annotated.csv
# STD_27_1_annotated.csv
# STD_66_1_annotated.csv
# STD_52_1_annotated.csv
# STD_24_1_annotated.csv
# STD_18_1_annotated.csv
# STD_48_1_annotated.csv
# STD_34_1_annotated.csv
# STD_60_1_annotated.csv
# STD_32_1_annotated.csv
# STD_44_1_annotated.csv
# STD_54_1_annotated.csv
# STD_26_1_annotated.csv
# STD_21_1_annotated.csv
# STD_59_1_annotated.csv
# STD_6_1_annotated.csv
# STD_53_1_annotated.csv
# STD_37_1_annotated.csv
# STD_11_1_annotated.csv
# STD_45_1_annotated.csv
# STD_25_1_annotated.csv
# STD_38_1_annotated.csv
# STD_16_1_annotated.csv
# STD_40_1_annotated.csv
# STD_10_1_annotated.csv
# STD_7_1_annotated.csv

# %%
mobidata = np.array(mobidata)
mobilabels = np.array(mobilabels)
mobicombined = (listOfTuples((torch.from_numpy(mobidata)).to(torch.float), torch.from_numpy(mobilabels).to(torch.float)))
random.shuffle(mobicombined)

# %%
get_acc(model_6, mobicombined, 64)
# Out:
# 0.9267047774601879

# %% [markdown]
# **Accuracy = 92.67%**
#
# **Sensitivity = 97.26%**
#
# **Specificity = 91.8%**

# %%
def get_acc_rev(model, data, batch_size):
  correct = 0
  total = 0
  error = 0
  out_list = torch.tensor([])
  for img, labels in torch.utils.data.DataLoader(data, batch_size = batch_size):
    output = model(img)
    output = torch.sigmoid(output) # Gets the decimal estimations of fall / no fall
    estimate = torch.round(output) # Rounds each estimate to 1 or 0 --> fall or no fall
    diff = torch.abs(estimate - labels, out=None) # Gets all the incorrect assessments equal to 1
    temp = torch.sum(diff) # Sums all the error estimates
    error = temp.item() + error

    out_list = torch.cat((out_list, output))

  label_list = get_labels(data)
  out_list = out_list.view(-1).cpu().detach().numpy()
  out_list = [round(i) for i in out_list]
  # confusion_matrix_2 = metrics.confusion_matrix(label_list, out_list)
  # cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix_2, display_labels = [0, 1])

  # cm_display.plot()
  # plt.show()
  if len(data) == 0:
    return None

  return 1 - error / len(data)

# %%
import re

# %%
subject_list = list(range(1, 68))
acc_matrix = [[]]
actdata = []
actlabels = []
acc_list = []
act_list = []
sub_list_order = []
for activity in ['STD', 'WAL', 'STU', 'STN', 'SIT', 'JOG', 'JUM', 'CSI', 'CSO', 'FOL', 'FKL', 'SDL', 'BSC']:

  for subject in subject_list:
    act_list.append(activity)
    sub_list_order.append(subject)

    print(subject)
    actdata = []
    actlabels = []
    sub_list = [subject]
    for dir, _, files in os.walk('/content/MobiAct_Dataset_v2.0/Annotated Data'):
      for file in files:
        sub = int(file[4:6].strip("_"))
        if file[:3] == activity and sub in sub_list:
          # print(file)
          file_df = pd.read_csv(os.path.join(dir, file))
          file_df = file_df.drop(['timestamp', 'azimuth', 'pitch', 'roll', 'label'], axis=1)
          file_df.rename(columns={'rel_time': 'Timestamp', 'acc_x': 'X_Acc_1', 'acc_y': 'Y_Acc_1', 'acc_z': 'Z_Acc_1','gyro_x': 'X_Gyro', 'gyro_y': 'Y_Gyro', 'gyro_z': 'Z_Gyro'}, inplace=True)
          file_df['X_Acc_1'] = file_df['X_Acc_1'] * -1
          file_df['Y_Acc_1'] = file_df['Y_Acc_1'] * -1
          file_df['Z_Acc_1'] = file_df['Z_Acc_1'] * -1
          file_df['X_Gyro'] = file_df['X_Gyro'] * -180/3.14
          file_df['Y_Gyro'] = file_df['Y_Gyro'] * -180/3.14
          file_df['Z_Gyro'] = file_df['Z_Gyro'] * -180/3.14
          if file[:3] in ['FOL', 'FKL', 'SDL', 'BSC']:
            last_row = file_df.tail(1)
            new_rows = pd.concat([last_row]*(3000-len(file_df)), ignore_index=True)
            file_df = pd.concat([file_df, new_rows], ignore_index=True)
            file_sampled = sampler.window_sample(file_df)
            actdata.append(file_sampled)
            actlabels.append(1)
          elif file[:3] in ['STD', 'WAL']:
            for i in range(0, 57000, 3000):
              file_df_i = file_df[i:i+3000]
              file_sampled = sampler.window_sample(file_df_i)
              actdata.append(file_sampled)
              actlabels.append(0)
          elif file[:3] in ['STU', 'STN', 'SIT', 'JOG', 'JUM', 'CSI', 'CSO']:
            if len(file_df)>3000:
              file_df = file_df[:3000]
            elif len(file_df)<3000:
              last_row = file_df.tail(1)
              new_rows = pd.concat([last_row]*(3000-len(file_df)), ignore_index=True)
              file_df = pd.concat([file_df, new_rows], ignore_index=True)
            file_sampled = sampler.window_sample(file_df)
            actdata.append(file_sampled)
            actlabels.append(0)

    print(f'{activity} Accuracy = {acc_act}% \t Number of Samples = {len(actlabels)}')
    actdata = np.array(actdata)
    actlabels = np.array(actlabels)
    actcombined = (listOfTuples((torch.from_numpy(actdata)).to(torch.float), torch.from_numpy(actlabels).to(torch.float)))
    random.shuffle(actcombined)
    acc_act = get_acc_rev(model_6, actcombined, 64)
    acc_list.append(acc_act)

    if acc_act != None:
      acc_act = acc_act * 100

    #print(f'{activity} Accuracy = {acc_act}% \t Number of Samples = {len(actlabels)}')
# Out:
# 1
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 2
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 3
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 4
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 5
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 6
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 7
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 8
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 9
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 10
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 11
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 12
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 13
# STD Accuracy = 100.0% 	 Number of Samples = 0
# 14
# STD Accuracy = None% 	 Number of Samples = 0
# 15
# STD Accuracy = None% 	 Number of Samples = 0
# 16
# STD Accuracy = None% 	 Number of Samples = 19
# 17
# STD Accuracy = 100.0% 	 Number of Samples = 0
# 18
# STD Accuracy = None% 	 Number of Samples = 19
# 19
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 20
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 21
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 22
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 23
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 24
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 25
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 26
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 27
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 28
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 29
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 30
# STD Accuracy = 100.0% 	 Number of Samples = 0
# 31
# STD Accuracy = None% 	 Number of Samples = 0
# 32
# STD Accuracy = None% 	 Number of Samples = 19
# 33
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 34
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 35
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 36
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 37
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 38
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 39
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 40
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 41
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 42
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 43
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 44
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 45
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 46
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 47
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 48
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 49
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 50
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 51
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 52
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 53
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 54
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 55
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 56
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 57
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 58
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 59
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 60
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 61
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 62
# STD Accuracy = 100.0% 	 Number of Samples = 0
# 63
# STD Accuracy = None% 	 Number of Samples = 19
# 64
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 65
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 66
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 67
# STD Accuracy = 100.0% 	 Number of Samples = 19
# 1
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 2
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 3
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 4
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 5
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 6
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 7
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 8
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 9
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 10
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 11
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 12
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 13
# WAL Accuracy = 100.0% 	 Number of Samples = 0
# 14
# WAL Accuracy = None% 	 Number of Samples = 0
# 15
# WAL Accuracy = None% 	 Number of Samples = 0
# 16
# WAL Accuracy = None% 	 Number of Samples = 19
# 17
# WAL Accuracy = 100.0% 	 Number of Samples = 0
# 18
# WAL Accuracy = None% 	 Number of Samples = 19
# 19
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 20
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 21
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 22
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 23
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 24
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 25
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 26
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 27
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 28
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 29
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 30
# WAL Accuracy = 100.0% 	 Number of Samples = 0
# 31
# WAL Accuracy = None% 	 Number of Samples = 0
# 32
# WAL Accuracy = None% 	 Number of Samples = 19
# 33
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 34
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 35
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 36
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 37
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 38
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 39
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 40
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 41
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 42
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 43
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 44
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 45
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 46
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 47
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 48
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 49
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 50
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 51
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 52
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 53
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 54
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 55
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 56
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 57
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 58
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 59
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 60
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 61
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 62
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 63
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 64
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 65
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 66
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 67
# WAL Accuracy = 100.0% 	 Number of Samples = 19
# 1
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 2
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 3
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 4
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 5
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 6
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 7
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 8
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 9
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 10
# STU Accuracy = 100.0% 	 Number of Samples = 5
# 11
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 12
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 13
# STU Accuracy = 100.0% 	 Number of Samples = 0
# 14
# STU Accuracy = None% 	 Number of Samples = 0
# 15
# STU Accuracy = None% 	 Number of Samples = 0
# 16
# STU Accuracy = None% 	 Number of Samples = 6
# 17
# STU Accuracy = 100.0% 	 Number of Samples = 0
# 18
# STU Accuracy = None% 	 Number of Samples = 6
# 19
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 20
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 21
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 22
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 23
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 24
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 25
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 26
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 27
# STU Accuracy = 100.0% 	 Number of Samples = 5
# 28
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 29
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 30
# STU Accuracy = 100.0% 	 Number of Samples = 0
# 31
# STU Accuracy = None% 	 Number of Samples = 0
# 32
# STU Accuracy = None% 	 Number of Samples = 6
# 33
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 34
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 35
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 36
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 37
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 38
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 39
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 40
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 41
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 42
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 43
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 44
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 45
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 46
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 47
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 48
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 49
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 50
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 51
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 52
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 53
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 54
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 55
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 56
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 57
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 58
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 59
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 60
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 61
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 62
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 63
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 64
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 65
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 66
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 67
# STU Accuracy = 100.0% 	 Number of Samples = 6
# 1
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 2
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 3
# STN Accuracy = 83.33333333333334% 	 Number of Samples = 6
# 4
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 5
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 6
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 7
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 8
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 9
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 10
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 11
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 12
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 13
# STN Accuracy = 100.0% 	 Number of Samples = 0
# 14
# STN Accuracy = None% 	 Number of Samples = 0
# 15
# STN Accuracy = None% 	 Number of Samples = 0
# 16
# STN Accuracy = None% 	 Number of Samples = 6
# 17
# STN Accuracy = 100.0% 	 Number of Samples = 0
# 18
# STN Accuracy = None% 	 Number of Samples = 6
# 19
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 20
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 21
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 22
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 23
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 24
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 25
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 26
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 27
# STN Accuracy = 100.0% 	 Number of Samples = 5
# 28
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 29
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 30
# STN Accuracy = 100.0% 	 Number of Samples = 0
# 31
# STN Accuracy = None% 	 Number of Samples = 0
# 32
# STN Accuracy = None% 	 Number of Samples = 6
# 33
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 34
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 35
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 36
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 37
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 38
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 39
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 40
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 41
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 42
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 43
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 44
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 45
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 46
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 47
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 48
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 49
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 50
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 51
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 52
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 53
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 54
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 55
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 56
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 57
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 58
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 59
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 60
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 61
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 62
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 63
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 64
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 65
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 66
# STN Accuracy = 100.0% 	 Number of Samples = 6
# 67
# STN Accuracy = 83.33333333333334% 	 Number of Samples = 6
# 1
# SIT Accuracy = 100.0% 	 Number of Samples = 1
# 2
# SIT Accuracy = 0.0% 	 Number of Samples = 1
# 3
# SIT Accuracy = 0.0% 	 Number of Samples = 1
# 4
# SIT Accuracy = 100.0% 	 Number of Samples = 0
# 5
# SIT Accuracy = None% 	 Number of Samples = 1
# 6
# SIT Accuracy = 100.0% 	 Number of Samples = 1
# 7
# SIT Accuracy = 100.0% 	 Number of Samples = 0
# 8
# SIT Accuracy = None% 	 Number of Samples = 0
# 9
# SIT Accuracy = None% 	 Number of Samples = 0
# 10
# SIT Accuracy = None% 	 Number of Samples = 0
# 11
# SIT Accuracy = None% 	 Number of Samples = 0
# 12
# SIT Accuracy = None% 	 Number of Samples = 1
# 13
# SIT Accuracy = 0.0% 	 Number of Samples = 0
# 14
# SIT Accuracy = None% 	 Number of Samples = 0
# 15
# SIT Accuracy = None% 	 Number of Samples = 0
# 16
# SIT Accuracy = None% 	 Number of Samples = 0
# 17
# SIT Accuracy = None% 	 Number of Samples = 0
# 18
# SIT Accuracy = None% 	 Number of Samples = 0
# 19
# SIT Accuracy = None% 	 Number of Samples = 0
# 20
# SIT Accuracy = None% 	 Number of Samples = 1
# 21
# SIT Accuracy = 0.0% 	 Number of Samples = 0
# 22
# SIT Accuracy = None% 	 Number of Samples = 0
# 23
# SIT Accuracy = None% 	 Number of Samples = 0
# 24
# SIT Accuracy = None% 	 Number of Samples = 0
# 25
# SIT Accuracy = None% 	 Number of Samples = 0
# 26
# SIT Accuracy = None% 	 Number of Samples = 0
# 27
# SIT Accuracy = None% 	 Number of Samples = 0
# 28
# SIT Accuracy = None% 	 Number of Samples = 0
# 29
# SIT Accuracy = None% 	 Number of Samples = 0
# 30
# SIT Accuracy = None% 	 Number of Samples = 0
# 31
# SIT Accuracy = None% 	 Number of Samples = 0
# 32
# SIT Accuracy = None% 	 Number of Samples = 0
# 33
# SIT Accuracy = None% 	 Number of Samples = 0
# 34
# SIT Accuracy = None% 	 Number of Samples = 0
# 35
# SIT Accuracy = None% 	 Number of Samples = 0
# 36
# SIT Accuracy = None% 	 Number of Samples = 0
# 37
# SIT Accuracy = None% 	 Number of Samples = 0
# 38
# SIT Accuracy = None% 	 Number of Samples = 0
# 39
# SIT Accuracy = None% 	 Number of Samples = 0
# 40
# SIT Accuracy = None% 	 Number of Samples = 0
# 41
# SIT Accuracy = None% 	 Number of Samples = 0
# 42
# SIT Accuracy = None% 	 Number of Samples = 0
# 43
# SIT Accuracy = None% 	 Number of Samples = 0
# 44
# SIT Accuracy = None% 	 Number of Samples = 0
# 45
# SIT Accuracy = None% 	 Number of Samples = 1
# 46
# SIT Accuracy = 0.0% 	 Number of Samples = 0
# 47
# SIT Accuracy = None% 	 Number of Samples = 0
# 48
# SIT Accuracy = None% 	 Number of Samples = 0
# 49
# SIT Accuracy = None% 	 Number of Samples = 0
# 50
# SIT Accuracy = None% 	 Number of Samples = 0
# 51
# SIT Accuracy = None% 	 Number of Samples = 0
# 52
# SIT Accuracy = None% 	 Number of Samples = 0
# 53
# SIT Accuracy = None% 	 Number of Samples = 1
# 54
# SIT Accuracy = 0.0% 	 Number of Samples = 0
# 55
# SIT Accuracy = None% 	 Number of Samples = 0
# 56
# SIT Accuracy = None% 	 Number of Samples = 0
# 57
# SIT Accuracy = None% 	 Number of Samples = 0
# 58
# SIT Accuracy = None% 	 Number of Samples = 1
# 59
# SIT Accuracy = 0.0% 	 Number of Samples = 1
# 60
# SIT Accuracy = 100.0% 	 Number of Samples = 1
# 61
# SIT Accuracy = 0.0% 	 Number of Samples = 1
# 62
# SIT Accuracy = 0.0% 	 Number of Samples = 1
# 63
# SIT Accuracy = 100.0% 	 Number of Samples = 1
# 64
# SIT Accuracy = 0.0% 	 Number of Samples = 1
# 65
# SIT Accuracy = 0.0% 	 Number of Samples = 1
# 66
# SIT Accuracy = 0.0% 	 Number of Samples = 1
# 67
# SIT Accuracy = 0.0% 	 Number of Samples = 1
# 1
# JOG Accuracy = 0.0% 	 Number of Samples = 3
# 2
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 3
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 4
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 5
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 6
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 7
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 8
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 9
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 10
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 11
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 12
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 13
# JOG Accuracy = 100.0% 	 Number of Samples = 0
# 14
# JOG Accuracy = None% 	 Number of Samples = 0
# 15
# JOG Accuracy = None% 	 Number of Samples = 0
# 16
# JOG Accuracy = None% 	 Number of Samples = 3
# 17
# JOG Accuracy = 100.0% 	 Number of Samples = 0
# 18
# JOG Accuracy = None% 	 Number of Samples = 3
# 19
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 20
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 21
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 22
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 23
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 24
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 25
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 26
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 27
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 28
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 29
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 30
# JOG Accuracy = 100.0% 	 Number of Samples = 0
# 31
# JOG Accuracy = None% 	 Number of Samples = 0
# 32
# JOG Accuracy = None% 	 Number of Samples = 3
# 33
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 34
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 35
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 36
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 37
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 38
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 39
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 40
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 41
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 42
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 43
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 44
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 45
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 46
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 47
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 48
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 49
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 50
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 51
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 52
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 53
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 54
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 55
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 56
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 57
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 58
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 59
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 60
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 61
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 62
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 63
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 64
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 65
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 66
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 67
# JOG Accuracy = 100.0% 	 Number of Samples = 3
# 1
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 2
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 3
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 4
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 5
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 6
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 7
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 8
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 9
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 10
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 11
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 12
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 13
# JUM Accuracy = 100.0% 	 Number of Samples = 0
# 14
# JUM Accuracy = None% 	 Number of Samples = 0
# 15
# JUM Accuracy = None% 	 Number of Samples = 0
# 16
# JUM Accuracy = None% 	 Number of Samples = 3
# 17
# JUM Accuracy = 100.0% 	 Number of Samples = 0
# 18
# JUM Accuracy = None% 	 Number of Samples = 3
# 19
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 20
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 21
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 22
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 23
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 24
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 25
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 26
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 27
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 28
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 29
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 30
# JUM Accuracy = 100.0% 	 Number of Samples = 0
# 31
# JUM Accuracy = None% 	 Number of Samples = 0
# 32
# JUM Accuracy = None% 	 Number of Samples = 3
# 33
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 34
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 35
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 36
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 37
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 38
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 39
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 40
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 41
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 42
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 43
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 44
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 45
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 46
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 47
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 48
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 49
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 50
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 51
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 52
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 53
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 54
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 55
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 56
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 57
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 58
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 59
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 60
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 61
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 62
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 63
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 64
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 65
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 66
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 67
# JUM Accuracy = 100.0% 	 Number of Samples = 3
# 1
# CSI Accuracy = 100.0% 	 Number of Samples = 6
# 2
# CSI Accuracy = 66.66666666666667% 	 Number of Samples = 6
# 3
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 4
# CSI Accuracy = 100.0% 	 Number of Samples = 6
# 5
# CSI Accuracy = 16.666666666666664% 	 Number of Samples = 6
# 6
# CSI Accuracy = 16.666666666666664% 	 Number of Samples = 6
# 7
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 8
# CSI Accuracy = 33.333333333333336% 	 Number of Samples = 6
# 9
# CSI Accuracy = 16.666666666666664% 	 Number of Samples = 6
# 10
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 11
# CSI Accuracy = 16.666666666666664% 	 Number of Samples = 6
# 12
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 13
# CSI Accuracy = 0.0% 	 Number of Samples = 0
# 14
# CSI Accuracy = None% 	 Number of Samples = 0
# 15
# CSI Accuracy = None% 	 Number of Samples = 0
# 16
# CSI Accuracy = None% 	 Number of Samples = 6
# 17
# CSI Accuracy = 0.0% 	 Number of Samples = 0
# 18
# CSI Accuracy = None% 	 Number of Samples = 6
# 19
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 20
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 21
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 22
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 23
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 24
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 25
# CSI Accuracy = 16.666666666666664% 	 Number of Samples = 6
# 26
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 27
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 28
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 29
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 30
# CSI Accuracy = 0.0% 	 Number of Samples = 0
# 31
# CSI Accuracy = None% 	 Number of Samples = 0
# 32
# CSI Accuracy = None% 	 Number of Samples = 6
# 33
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 34
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 35
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 36
# CSI Accuracy = 0.0% 	 Number of Samples = 4
# 37
# CSI Accuracy = 25.0% 	 Number of Samples = 6
# 38
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 39
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 40
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 41
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 42
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 43
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 44
# CSI Accuracy = 16.666666666666664% 	 Number of Samples = 6
# 45
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 46
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 47
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 48
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 49
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 50
# CSI Accuracy = 0.0% 	 Number of Samples = 0
# 51
# CSI Accuracy = None% 	 Number of Samples = 6
# 52
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 53
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 54
# CSI Accuracy = 83.33333333333334% 	 Number of Samples = 6
# 55
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 56
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 57
# CSI Accuracy = 16.666666666666664% 	 Number of Samples = 6
# 58
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 59
# CSI Accuracy = 50.0% 	 Number of Samples = 6
# 60
# CSI Accuracy = 83.33333333333334% 	 Number of Samples = 6
# 61
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 62
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 63
# CSI Accuracy = 100.0% 	 Number of Samples = 6
# 64
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 65
# CSI Accuracy = 33.333333333333336% 	 Number of Samples = 6
# 66
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 67
# CSI Accuracy = 0.0% 	 Number of Samples = 6
# 1
# CSO Accuracy = 0.0% 	 Number of Samples = 6
# 2
# CSO Accuracy = 66.66666666666667% 	 Number of Samples = 6
# 3
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 4
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 5
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 6
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 7
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 8
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 9
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 10
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 11
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 12
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 13
# CSO Accuracy = 100.0% 	 Number of Samples = 0
# 14
# CSO Accuracy = None% 	 Number of Samples = 0
# 15
# CSO Accuracy = None% 	 Number of Samples = 0
# 16
# CSO Accuracy = None% 	 Number of Samples = 6
# 17
# CSO Accuracy = 100.0% 	 Number of Samples = 0
# 18
# CSO Accuracy = None% 	 Number of Samples = 6
# 19
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 20
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 21
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 22
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 23
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 24
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 25
# CSO Accuracy = 83.33333333333334% 	 Number of Samples = 6
# 26
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 27
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 28
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 29
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 30
# CSO Accuracy = 100.0% 	 Number of Samples = 0
# 31
# CSO Accuracy = None% 	 Number of Samples = 0
# 32
# CSO Accuracy = None% 	 Number of Samples = 6
# 33
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 34
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 35
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 36
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 37
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 38
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 39
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 40
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 41
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 42
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 43
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 44
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 45
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 46
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 47
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 48
# CSO Accuracy = 83.33333333333334% 	 Number of Samples = 6
# 49
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 50
# CSO Accuracy = 100.0% 	 Number of Samples = 0
# 51
# CSO Accuracy = None% 	 Number of Samples = 6
# 52
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 53
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 54
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 55
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 56
# CSO Accuracy = 83.33333333333334% 	 Number of Samples = 6
# 57
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 58
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 59
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 60
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 61
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 62
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 63
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 64
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 65
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 66
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 67
# CSO Accuracy = 100.0% 	 Number of Samples = 6
# 1
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 2
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 3
# FOL Accuracy = 66.66666666666667% 	 Number of Samples = 3
# 4
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 5
# FOL Accuracy = 66.66666666666667% 	 Number of Samples = 3
# 6
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 7
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 8
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 9
# FOL Accuracy = 66.66666666666667% 	 Number of Samples = 3
# 10
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 11
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 12
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 13
# FOL Accuracy = 66.66666666666667% 	 Number of Samples = 3
# 14
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 15
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 16
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 17
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 18
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 19
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 20
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 21
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 22
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 23
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 24
# FOL Accuracy = 100.0% 	 Number of Samples = 0
# 25
# FOL Accuracy = None% 	 Number of Samples = 3
# 26
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 27
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 28
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 29
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 30
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 31
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 32
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 33
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 34
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 35
# FOL Accuracy = 33.333333333333336% 	 Number of Samples = 3
# 36
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 37
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 38
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 39
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 40
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 41
# FOL Accuracy = 100.0% 	 Number of Samples = 0
# 42
# FOL Accuracy = None% 	 Number of Samples = 3
# 43
# FOL Accuracy = 66.66666666666667% 	 Number of Samples = 3
# 44
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 45
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 46
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 47
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 48
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 49
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 50
# FOL Accuracy = 100.0% 	 Number of Samples = 0
# 51
# FOL Accuracy = None% 	 Number of Samples = 3
# 52
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 53
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 54
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 55
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 56
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 57
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 58
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 59
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 60
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 61
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 62
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 63
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 64
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 65
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 66
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 67
# FOL Accuracy = 100.0% 	 Number of Samples = 3
# 1
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 2
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 3
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 4
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 5
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 6
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 7
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 8
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 9
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 10
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 11
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 12
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 13
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 14
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 15
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 16
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 17
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 18
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 19
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 20
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 21
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 22
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 23
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 24
# FKL Accuracy = 100.0% 	 Number of Samples = 0
# 25
# FKL Accuracy = None% 	 Number of Samples = 3
# 26
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 27
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 28
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 29
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 30
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 31
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 32
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 33
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 34
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 35
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 36
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 37
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 38
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 39
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 40
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 41
# FKL Accuracy = 100.0% 	 Number of Samples = 0
# 42
# FKL Accuracy = None% 	 Number of Samples = 3
# 43
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 44
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 45
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 46
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 47
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 48
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 49
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 50
# FKL Accuracy = 100.0% 	 Number of Samples = 0
# 51
# FKL Accuracy = None% 	 Number of Samples = 3
# 52
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 53
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 54
# FKL Accuracy = 33.333333333333336% 	 Number of Samples = 3
# 55
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 56
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 57
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 58
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 59
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 60
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 61
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 62
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 63
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 64
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 65
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 66
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 67
# FKL Accuracy = 100.0% 	 Number of Samples = 3
# 1
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 2
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 3
# SDL Accuracy = 66.66666666666667% 	 Number of Samples = 3
# 4
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 5
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 6
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 7
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 8
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 9
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 10
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 11
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 12
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 13
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 14
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 15
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 16
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 17
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 18
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 19
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 20
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 21
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 22
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 23
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 24
# SDL Accuracy = 100.0% 	 Number of Samples = 0
# 25
# SDL Accuracy = None% 	 Number of Samples = 3
# 26
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 27
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 28
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 29
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 30
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 31
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 32
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 33
# SDL Accuracy = 66.66666666666667% 	 Number of Samples = 3
# 34
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 35
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 36
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 37
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 38
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 39
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 40
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 41
# SDL Accuracy = 100.0% 	 Number of Samples = 0
# 42
# SDL Accuracy = None% 	 Number of Samples = 3
# 43
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 44
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 45
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 46
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 47
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 48
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 49
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 50
# SDL Accuracy = 100.0% 	 Number of Samples = 0
# 51
# SDL Accuracy = None% 	 Number of Samples = 3
# 52
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 53
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 54
# SDL Accuracy = 66.66666666666667% 	 Number of Samples = 3
# 55
# SDL Accuracy = 66.66666666666667% 	 Number of Samples = 3
# 56
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 57
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 58
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 59
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 60
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 61
# SDL Accuracy = 66.66666666666667% 	 Number of Samples = 3
# 62
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 63
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 64
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 65
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 66
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 67
# SDL Accuracy = 100.0% 	 Number of Samples = 3
# 1
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 2
# BSC Accuracy = 66.66666666666667% 	 Number of Samples = 3
# 3
# BSC Accuracy = 100.0% 	 Number of Samples = 2
# 4
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 5
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 6
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 7
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 8
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 9
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 10
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 11
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 12
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 13
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 14
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 15
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 16
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 17
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 18
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 19
# BSC Accuracy = 66.66666666666667% 	 Number of Samples = 3
# 20
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 21
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 22
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 23
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 24
# BSC Accuracy = 100.0% 	 Number of Samples = 0
# 25
# BSC Accuracy = None% 	 Number of Samples = 3
# 26
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 27
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 28
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 29
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 30
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 31
# BSC Accuracy = 66.66666666666667% 	 Number of Samples = 3
# 32
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 33
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 34
# BSC Accuracy = 66.66666666666667% 	 Number of Samples = 3
# 35
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 36
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 37
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 38
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 39
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 40
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 41
# BSC Accuracy = 100.0% 	 Number of Samples = 0
# 42
# BSC Accuracy = None% 	 Number of Samples = 3
# 43
# BSC Accuracy = 66.66666666666667% 	 Number of Samples = 3
# 44
# BSC Accuracy = 66.66666666666667% 	 Number of Samples = 3
# 45
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 46
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 47
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 48
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 49
# BSC Accuracy = 66.66666666666667% 	 Number of Samples = 3
# 50
# BSC Accuracy = 100.0% 	 Number of Samples = 0
# 51
# BSC Accuracy = None% 	 Number of Samples = 3
# 52
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 53
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 54
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 55
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 56
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 57
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 58
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 59
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 60
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 61
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 62
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 63
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 64
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 65
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 66
# BSC Accuracy = 100.0% 	 Number of Samples = 3
# 67
# BSC Accuracy = 100.0% 	 Number of Samples = 3

# %%
acc_matrix
# Out:
# [[]]

# %%
len(acc_list)
# Out:
# 871

# %%
len(act_list)
# Out:
# 871

# %%
df = pd.DataFrame({"Accuracy":acc_list, "Action": act_list, "Subject": sub_list_order})
df.to_csv('/content/MobiAct_acc_list.csv')
